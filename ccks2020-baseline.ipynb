# %% [markdown]
# # CCKS 2020: 基于本体的金融知识图谱自动化构建技术评测
#
# 竞赛背景
# 金融研报是各类金融研究结构对宏观经济、金融、行业、产业链以及公司的研究报告。报告通常是有专业人员撰写，对宏观、行业和公司的数据信息搜集全面、研究深入，质量高，内容可靠。报告内容往往包含产业、经济、金融、政策、社会等多领域的数据与知识，是构建行业知识图谱非常关键的数据来源。另一方面，由于研报本身所容纳的数据与知识涉及面广泛，专业知识众多，不同的研究结构和专业认识对相同的内容的表达方式也会略有差异。这些特点导致了从研报自动化构建知识图谱困难重重，解决这些问题则能够极大促进自动化构建知识图谱方面的技术进步。
#
# 本评测任务参考 TAC KBP 中的 Cold Start 评测任务的方案，围绕金融研报知识图谱的自动化图谱构建所展开。评测从预定义图谱模式（Schema）和少量的种子知识图谱开始，从非结构化的文本数据中构建知识图谱。其中图谱模式包括 10 种实体类型，如机构、产品、业务、风险等；19 个实体间的关系，如(机构，生产销售，产品)、(机构，投资，机构)等；以及若干实体类型带有属性，如（机构，英文名）、（研报，评级）等。在给定图谱模式和种子知识图谱的条件下，评测内容为自动地从研报文本中抽取出符合图谱模式的实体、关系和属性值，实现金融知识图谱的自动化构建。所构建的图谱在大金融行业、监管部门、政府、行业研究机构和行业公司等应用非常广泛，如风险监测、智能投研、智能监管、智能风控等，具有巨大的学术价值和产业价值。
#
# 评测本身不限制各参赛队伍使用的模型、算法和技术。希望各参赛队伍发挥聪明才智，构建各类无监督、弱监督、远程监督、半监督等系统，迭代的实现知识图谱的自动化构建，共同促进知识图谱技术的进步。
#
# 竞赛任务
# 本评测任务参考 TAC KBP 中的 Cold Start 评测任务的方案，围绕金融研报知识图谱的自动化图谱构建所展开。评测从预定义图谱模式（Schema）和少量的种子知识图谱开始，从非结构化的文本数据中构建知识图谱。评测本身不限制各参赛队伍使用的模型、算法和技术。希望各参赛队伍发挥聪明才智，构建各类无监督、弱监督、远程监督、半监督等系统，迭代的实现知识图谱的自动化构建，共同促进知识图谱技术的进步。
#
# 主办方邮箱  wangwenguang@datagrand.com kdd.wang@gmail.com
#
#
# 参考：https://www.biendata.com/competition/ccks_2020_5/

# %%
import json
import logging
import os
import random
import re
from collections import defaultdict
from pathlib import Path

# import attr
import tqdm
import hanlp
import numpy as np
import torch
import torch.optim
import torch.utils.data
from torch.nn import functional as F
from torchcrf import CRF
from pytorch_transformers import BertModel, BertTokenizer
import jieba
from jieba.analyse.tfidf import TFIDF
from jieba.posseg import POSTokenizer
import jieba.posseg as pseg
from itertools import product

# %% [markdown]
# # 预处理函数
#
# 对文章进行预处理，切分句子和子句等

# %%
def split_to_sents(content, filter_length=(2, 1000)):
    content = re.sub(r"\s*", "", content)
    content = re.sub("([。！…？?!；;])", "\\1\1", content)
    sents = content.split("\1")
    sents = [_[: filter_length[1]] for _ in sents]
    return [_ for _ in sents
            if filter_length[0] <= len(_) <= filter_length[1]]

def split_to_subsents(content, filter_length=(2, 1000)):
    content = re.sub(r"\s*", "", content)
    content = re.sub("([。！…？?!；;,，])", "\\1\1", content)
    sents = content.split("\1")
    sents = [_[: filter_length[1]] for _ in sents]
    return [_ for _ in sents
            if filter_length[0] <= len(_) <= filter_length[1]]

# %%
def read_json(file_path):
    with open(file_path, mode='r', encoding='utf8') as f:
        return json.load(f)

# %% [markdown]
# # 预训练模型配置
#
# 参考 https://github.com/huggingface/pytorch-transformers 下载预训练模型，并配置下面参数为相关路径
#
# ```python
# PRETRAINED_BERT_MODEL_DIR = '/you/path/to/bert-base-chinese/'
# ```

# %%
PRETRAINED_BERT_MODEL_DIR = '/home/wangwenguang/bigdata/wke-data/pretrained_models/bert-base-chinese/'

# %% [markdown]
# # 一些参数

# %%
DATA_DIR = './data'  # 输入数据文件夹
OUT_DIR = './output'  # 输出文件夹

Path(OUT_DIR).mkdir(exist_ok=True)

BATCH_SIZE = 32
TOTAL_EPOCH_NUMS = 10
if torch.cuda.is_available():
    DEVICE = 'cuda:0'
else:
    DEVICE = 'cpu'
YANBAO_DIR_PATH = str(Path(DATA_DIR, 'yanbao_txt'))
SAVE_MODEL_DIR = str(OUT_DIR)

# %% [markdown]
# ## 读入原始数据
#
# - 读入：所有研报内容
# - 读入：原始训练实体数据

# %%
yanbao_texts = []
for yanbao_file_path in Path(YANBAO_DIR_PATH).glob('*.txt'):
    with open(yanbao_file_path) as f:
        yanbao_texts.append(f.read())
#         if len(yanbao_texts) == 10:
#             break

# 来做官方的实体训练集，后续会混合来自第三方工具，规则，训练数据来扩充模型训练数据
to_be_trained_entities = read_json(Path(DATA_DIR, 'entities.json'))

# %% [markdown]
# # 用hanlp进行实体识别
#
# hanlp支持对人物、机构的实体识别，可以使用它来对其中的两个实体类型进行识别：人物、机构。
#
# hanlp见[https://github.com/hankcs/HanLP](https://github.com/hankcs/HanLP)

# %%
## NER by third party tool
class HanlpNER:
    def __init__(self):
        self.recognizer = hanlp.load(hanlp.pretrained.ner.MSRA_NER_BERT_BASE_ZH)
        self.max_sent_len = 126
        self.ent_type_map = {
            'NR': '人物',
            'NT': '机构'
        }
        self.black_list = {'公司'}

    def recognize(self, sent):
        entities_dict = {}
        for result in self.recognizer.predict([list(sent)]):
            for entity, hanlp_ent_type, _, _ in result:
                if not re.findall(r'^[\.\s\da-zA-Z]{1,2}$', entity) and \
                        len(entity) > 1 and entity not in self.black_list \
                        and hanlp_ent_type in self.ent_type_map:
                    entities_dict.setdefault(self.ent_type_map[hanlp_ent_type], []).append(entity)
        return entities_dict

# %%
def aug_entities_by_third_party_tool():
    hanlpner = HanlpNER()
    entities_by_third_party_tool = defaultdict(list)
    for file in tqdm.tqdm(list(Path(DATA_DIR, 'yanbao_txt').glob('*.txt'))[:]):
        with open(file, encoding='utf-8') as f:
            sents = [[]]
            cur_sent_len = 0
            for line in f:
                for sent in split_to_subsents(line):
                    sent = sent[:hanlpner.max_sent_len]
                    if cur_sent_len + len(sent) > hanlpner.max_sent_len:
                        sents.append([sent])
                        cur_sent_len = len(sent)
                    else:
                        sents[-1].append(sent)
                        cur_sent_len += len(sent)
            sents = [''.join(_) for _ in sents]
            sents = [_ for _ in sents if _]
            for sent in sents:
                entities_dict = hanlpner.recognize(sent)
                for ent_type, ents in entities_dict.items():
                    entities_by_third_party_tool[ent_type] += ents

    for ent_type, ents in entities_by_third_party_tool.items():
        entities_by_third_party_tool[ent_type] = list([ent for ent in set(ents) if len(ent) > 1])
    return entities_by_third_party_tool

# %%
# 此任务十分慢, 但是只需要运行一次
entities_by_third_party_tool = aug_entities_by_third_party_tool()
for ent_type, ents in entities_by_third_party_tool.items():
    to_be_trained_entities[ent_type] = list(set(to_be_trained_entities[ent_type] + ents))
# Out:
# Executing op Range in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op HashTableV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op LookupTableImportV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Add in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op LogicalNot in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Assert in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TruncatedNormal in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Done loading 197 BERT weights from: /home/wangwenguang/.hanlp/thirdparty/storage.googleapis.com/bert_models/2018_11_03/chinese_L-12_H-768_A-12/bert_model.ckpt into <bert.model.BertModelLayer object at 0x7fd5765f1490> (prefix:bert). Count of weights not found in the checkpoint was: [0]. Count of weights with mismatched shape: [0]
# Unused weights from checkpoint:
# 	bert/pooler/dense/bias
# 	bert/pooler/dense/kernel
# 	cls/predictions/output_bias
# 	cls/predictions/transform/LayerNorm/beta
# 	cls/predictions/transform/LayerNorm/gamma
# 	cls/predictions/transform/dense/bias
# 	cls/predictions/transform/dense/kernel
# 	cls/seq_relationship/output_bias
# 	cls/seq_relationship/output_weights
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
#   0%|          | 0/200 [00:00<?, ?it/s]
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AnonymousIteratorV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MakeIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op IteratorGetNextSync in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Shape in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StridedSlice in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_function_10097 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ExpandDims in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op NotEqual in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op All in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ArgMax in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Shape in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StridedSlice in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Prod in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StridedSlice in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StridedSlice in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Pack in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ConcatV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Where in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Squeeze in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op GatherV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StridedSlice in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op DeleteIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
#   0%|          | 1/200 [00:10<35:22, 10.67s/it]
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
#   1%|          | 2/200 [00:14<28:07,  8.52s/it]
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
#   2%|▏         | 3/200 [00:24<29:28,  8.98s/it]
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
#   2%|▏         | 4/200 [00:30<26:23,  8.08s/it]
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# ...
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# 100%|█████████▉| 199/200 [25:32<00:11, 11.10s/it]
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PaddedBatchDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# 100%|██████████| 200/200 [25:41<00:00,  7.71s/it]

# %%
for k, v in entities_by_third_party_tool.items():
    print(k)
    print(set(v))
# Out:
# 机构
# {'北京智能车联产业创新中心有限公司', '上海治臻', '中环股份', '合众', '锐翔上房', 'GlandPharma', '瑞士航空', '光大永明', '苏宁易购', '菜鸟', '世纪互联', '微芯科技', '中化新网', 'sla', '安卓', '江苏安靠智能输电工程科技股份有限公司', '仙琚制药', '中国饭店协会', '荣泰健康', '生殖中心', '三星公司', '碧桂园服务', 'SilverCross', '大洋电机', '美国戈尔', '上能电气', '武汉理工新能源', '鲁北集团', '中科蓝讯', '搜狐网', '金界控股', 'WTI', '雅虎', '中国智能交通产业联盟', 'CR5', 'IVF', 'CRO', 'Emulex', '小天鹅', '蓝光发展', '）第五届董事会', '美的集团', '坎伯兰电话公司', '大众品上市公司', '纽交所', '世界组织', '2019H1公司', '药明生物', '“7-11”便利店', '人行', '雅居乐地产控股有限公司', '西囡医院', '新疆金风科技股份有限公司', '人民网', '络达', '海油', 'Lumentum', '加州医学公司', '鸿基创能', '腾讯科技',
# {'梅耶博格', '王力宏', '温家宝', '尼克松', 'rederic', '李大龙', '奥巴马', 'Yoshizawa', '真木', '李佳琦', '张智刚', '科特·凯尔迪', '吴仪', '钟南山', '毛伟明', '钱纳里', '埃斯顿', '美亚', '克林顿', '戴维', '弗若斯特沙利文', '杨成', '堀切', '汤普森', '茂木七郎右卫门', '李兰娟', '曹德旺', '布什', '如涵', '管毅宏', '钟发平', '林平', '苗圩', '马东生', '戴庆华', '陈卓林', '伍德麦肯兹', '孟山都', '.Kurzius', '曾勇', '科再奇', '池玲', '特朗普', '习近平', '王振营', 'KurtKelty', '叶继德', 'esla', '梁孟松', '杨光', '加内特', '黄勇军', '梁念坚', '莉莉丝', 'Kelty', 'Lawr', '西囡', 'OPPO', '申屠', '茂木', 'CEO埃隆·马斯克', '何小鹏', 'dfordA.Kolb', '里根', '寇伟', '津贺一宏', '梅田博和', '茂木友三郎', '默沙东', '薇娅', '马太', '杨光磊', '梅骅', '黄海', '斯科拉', '冯飞', 'nman', 'Musk', '科力远', 'Kurzius', 'oLaCamera', '宁吉喆', '秦力洪', '杨菲', '新能源', '贝斯特', 'Frances', '龟甲万', '李檬', '贲敏', '松下幸之助', 'ElonMusk', '袁旭成', '申屠献忠', '程艺龙', '吴凯', '蒋建强', 'oonstafar', '高梨', '海沃德', '王勃华', '那未', '菲利普斯', '摩尔', '郭磊', '丁敏华', '冯欣', '王岐山', '阿扎', '钟影', '颜卫彬', '.Wilcox', '马斯克', '花西子'}

# %% [markdown]
# ## 通过规则抽取实体
#
# - 机构
# - 研报
# - 文章
# - 风险

# %%
def aug_entities_by_rules(yanbao_dir):
    entities_by_rule = defaultdict(list)
    for file in list(yanbao_dir.glob('*.txt'))[:]:
        with open(file, encoding='utf-8') as f:
            found_yanbao = False
            found_fengxian = False
            for lidx, line in enumerate(f):
                # 公司的标题
                ret = re.findall('^[\(（]*[\d一二三四五六七八九十①②③④⑤]*[\)）\.\s]*(.*有限公司)$', line)
                if ret:
                    entities_by_rule['机构'].append(ret[0])
                    
                # 研报
                if not found_yanbao and lidx <= 5 and len(line) > 10:
                    may_be_yanbao = line.strip()
                    if not re.findall(r'\d{4}\s*[年-]\s*\d{1,2}\s*[月-]\s*\d{1,2}\s*日?', may_be_yanbao) \
                            and not re.findall('^[\d一二三四五六七八九十]+\s*[\.、]\s*.*$', may_be_yanbao) \
                            and not re.findall('[\(（]\d+\.*[A-Z]*[\)）]', may_be_yanbao) \
                            and len(may_be_yanbao) > 5:
                        entities_by_rule['研报'].append(may_be_yanbao)
                        found_yanbao = True

                # 文章
                for sent in split_to_sents(line):
                    results = re.findall('《(.*?)》', sent)
                    for result in results:
                        entities_by_rule['文章'].append(result)     

                # 风险
                for sent in split_to_sents(line):
                    if found_fengxian:
                        sent = sent.split('：')[0]
                        fengxian_entities = re.split('以及|、|，|；|。', sent)
                        fengxian_entities = [re.sub('^[■]+[\d一二三四五六七八九十①②③④⑤]+', '', ent) for ent in fengxian_entities]
                        fengxian_entities = [re.sub('^[\(（]*[\d一二三四五六七八九十①②③④⑤]+[\)）\.\s]+', '', ent) for ent in fengxian_entities]
                        fengxian_entities = [_ for _ in fengxian_entities if len(_) >=4]
                        entities_by_rule['风险'] += fengxian_entities
                        found_fengxian = False
                    if not found_fengxian and re.findall('^\s*[\d一二三四五六七八九十]*\s*[\.、]*\s*风险提示[:：]*$', sent):
                        found_fengxian = True
                    
                    results = re.findall('^\s*[\d一二三四五六七八九十]*\s*[\.、]*\s*风险提示[:：]*(.{5,})$', sent)
                    if results:
                        fengxian_entities = re.split('以及|、|，|；|。', results[0])
                        fengxian_entities = [re.sub('^[■]+[\d一二三四五六七八九十①②③④⑤]+', '', ent) for ent in fengxian_entities]
                        fengxian_entities = [re.sub('^[\(（]*[\d一二三四五六七八九十①②③④⑤]+[\)）\.\s]+', '', ent) for ent in fengxian_entities]
                        fengxian_entities = [_ for _ in fengxian_entities if len(_) >=4]
                        entities_by_rule['风险'] += fengxian_entities
                    
    for ent_type, ents in entities_by_rule.items():
        entities_by_rule[ent_type] = list(set(ents))
    return entities_by_rule

# %%
# 通过规则来寻找新的实体
entities_by_rule = aug_entities_by_rules(Path(DATA_DIR, 'yanbao_txt'))
for ent_type, ents in entities_by_rule.items():
    to_be_trained_entities[ent_type] = list(set(to_be_trained_entities[ent_type] + ents))

# %%
for k, v in entities_by_rule.items():
    print(k)
    print(set(v))
# Out:
# 研报
# {'证券研究报告/行业深度报告', '公司研究/房地产/房地产', '从FILA到Amer，新起点与新征程', '深度产业运营+投资，健康、快乐、富足生态步入收获期', '2019年业绩前瞻：稳健增长的一年', '手机产业系列报告之二', '餐饮行业系列专题九：“看不见”的金矿——餐饮供应链', 'Wi-Fi6：拐点已至', '鉴彼时以观今日，化工行业疫情影响解析', '机械设备2020：拥抱科创，关注周期波动，把握核心资产', '潮平两岸阔，风正一帆悬', '物流运输略有好转，农资产品价格上行', '创新人力资源领导者，灵活用工驱动高成长', '半导体行情的风险是什么', '布局弹性，早周期领跑', '百年疫情史：病毒改变了啥？', '疫情冲击旅游业既定预期，短期业绩承压，静候细分龙头复苏', '迈过泥泞，方成涅槃——短期影响不改行业趋势，龙头公司韧性逐渐体现', '消失的需求，创造的消费，递延的社交——从需求类别看疫情对食品饮料行业的影响', '19 年 Q4 业绩胜预期；公司业务具韧性', '招银国际证券 | 睿智投资 | 公司研究', '国内海洋油气龙头，成本低、油价弹性大', '中国飞鹤：正式纳入港股通，积极应对疫情保障正常运营，品牌力和竞争优势进一步强化', '大消费联合系列报告：不可忽视的刚需消费', '证券研究报告•行业研究•汽车', '优质赛道龙头，塑造卓越品牌', '2020 有望恢复增长，估值仍处低位', '受益于微信商业生态提速', '新冠疫情医药行业专题报告', '他山之石，从龟甲万、味好美看调味品公司发展路径', '从两化协同看我国农业自主可控大格局', '高品质服务+跨越式成长，长期价值可期', '受疫情影响相对较小，短期车险赔付率有望改善', '公告点评|耐用消费品与服装', '寿险销售的逆周期性与投资的稳定性', '证券研究报告|行业周报', '双寡头格局初现，高镍三元方向不可撼动', '证券研究报告·行业研究·文化传媒', '赛道优势显著，国际化辅助生殖新星崭露头角', '行业报告|行业研究周报', '游戏强劲，在线教育迎风起航', '特斯拉有望重塑中国车市格局，看好从零到一的机会', '危废垃圾双轮驱动，政策利好助力成长', '特斯拉始入华，探析市场竞争力', '光伏设备行业报告：PERC 持续高景气,大尺寸及 HJT 引领设备迭代', '国产化进程加快，补贴有望向上游零部件靠拢', '社融超预期，把握行情机会', '特斯拉专题系列报告（一）：', '新的起点，从5G看云', '羊奶粉龙头，业绩增长稳健', '内外两维度看美股风险收益比', '证券研究报告/行业动态报告', '持续改善中的电动车龙头', '行业 非必需性消费/旅游及消闲设施', '粮食会是明年通胀的风险因素吗', '携手“鲲鹏”，展翅入“云”', '软磁：无线充电开启黄金时代', '推荐（首次）风险评级：中风险', '从SARS疫情复盘看新型冠状病毒肺炎对机械行业的影响', '继续深挖低线城市业务发展机会', '交运角度看复工：进度、优缺点与交叉验证', '远程办公产品之多媒体融合全面体验', '行业评级强于大市(维持评级)上次评级强于大市', '拳头游戏下行，静待新游接棒', '央企物管旗舰驶入非住宅物业蓝海', '一城一策持续放松，货币财政双双发力', '4季度中场业务仍然有所增长', '疫情影响分析：主要区域和产业链、供应链冲', '西北菜&酸菜鱼龙头，规模化扩张与品质化提升并举', '疫情后的修复能力强，公司长期价值显著', '评级：买入上次评级：买入', '重构新消费：社交资产如何链接“品”与“效”', '赋能全球生物药研发的 CRO/CDMO 龙头'}
# 风险
# {'宏观经济下行风险', '行业资金超预期收紧', '北美主要客户需求增长不及预期', '棋牌类游戏监管政策趋严', '广告业务变现不及预期', '新产品研发及推广进度不及预期', '小程序发展不及预期', '宏观经济恢复进度不达预期', '房地产宏观政策风险', '2019-nCoV病毒快速变异', '金界三期进度慢于预期风险', '影响公司毛利率', '业务发展不及预期等', 'SaaS收入增长不及预期', '研发进度不达预期', '大陆多个8寸厂开出后行业竞争加剧', '亏损扩大', '电动车渗透率增速不及预期', '对公司增长带来影响', '房地产调控政策超预期收紧', 'ModelY产品交付不及预期等风险', '基建/地产投资增速下滑', '下游功率器件需求放缓', '技术研发不及预期', '影响车企销量', '新型冠状病毒感染肺炎疫情程度超出市场预期', '行业复苏乏力', '疫情反复超预期', '科室学科共建管理服务模式存在的风险', '政策支持力度低于预期', '“晶圓代工扩产计划所拉高的折旧费用可能破坏毛利结构', '下游扩产进度放缓', '半导体项目推进不达预期', '行业需求萎缩', '市场竞争激烈风险', '工程机械销量陡降', '车市下行风险', '新游上线进程及上线后表现不达预期', '内地疫情扩散的风险', '贷款利率下行较快压制息差', '用户活跃度下降风险', '销售不及预期', '并购低于预期风险', '数据资源安全风险', '公司管理效率提升不及预期', '贸易战影响海外需求', '美国经济超预期', '宏观经济增速放缓', '①供应链发展速度无法匹配直播电商发展速度的风险', '微信商业生态发展不及预期', '可穿戴设备出货量增长低于预期', '全球产能松动', '中美贸易摩擦超预期', '部分厂商远程办公产品推广可能不及预期', '新能源汽车销量不及预期', '原油价格大幅波动', '东南亚博彩市场竞争加剧风险', '上游零部件和制氢成本下降幅度不及预期', '老游戏收入增长放缓', '基建投资增速不及预期', '疫情发展超预期风险', '宏观经济下行导致新能源车需求下降', '疫情发展的不确定性', '市场竞争激烈', '12“晶圆代工扩产计划所拉高的折旧费用可能持续破坏整体毛利结构', '疫情扩散程度超预期', '并购整合不及预期', '车市竞争继续恶化', '无锡厂不能按期量产', '疫情加剧', '产销量不及预期风险', '外资企业竞争加剧', '而与市场预估值的差异是短期所面临的风险', '行业竞争致获客成本增长', '中美贸易摩擦加剧', '制造业投资景气度不及预期', '政策放松不及预期', '新品研发进度不及预期', '业务整合效果不及预期', '签证政策收紧', '新半导体器件工艺替代', '工业缝纫机行业景气度不及预期', '病虫害超预期爆发', '14nm工艺进展不及预期', '国际环境变化', '部分银行资产质量波动', '各类新项目建设及投产进度不及预期', '新冠
欧洲生产研发基地的议案', '关于2016-2020年新能源汽车推广应用财政支持政策的通知', '汽车产业调整和振兴规划', '国家卫生计生委关于规范人类辅助生殖技术与人类精子库审批的补充规定', '深圳证券交易所创业板股票上市规则', '道路机动车辆生产企业及产品公告', '关于存量分布式光伏电站补贴申报有关事项的通知', '关于开展节能和新能源汽车示范推广试点工作的通知', '人类辅助生殖技术管理办法', '庆余年', '战略合作协议书', '卧龙吟', '雅居乐集团新型冠状病毒防控工作应急预案', '剑歌行', '光伏制造行业规范条件', '部分产能过剩行业产能置换实施办法', '国家中长期人才发展规划纲要（2010-2020）', '装配式建筑综合效益分析方法研究', '2019年度中国电动汽车充电设施技术发展白皮书之二：无线充电', '公司注册证明书', '光伏发电站设计规范（征求意见稿）', '旅游住宅物业服务规范', '可再生能源发展专项资金管理暂行办法', '关于做好地方政府专项债券发行及项目配套融资工作的通知', 'EvolutionofthenovelcoronavirusfromtheongoingWuhanoutbreakandmodelingofitsspikeproteinforriskofhumantransmission', '绿色发展行动计划', '中国羊奶粉产业发展研究', '国家知识产权局关于“林平P及图”等商标案件请示的批复', '传染病防治法', '中国疾病预防控制工作进展(2015)报告', '跳舞的线', '安踏收购Amer，从优秀到卓越的起点', '商标法实施条例', '合肥市城市轨道交通第三期建设规划（2019-2024年）', '特斯拉秘密宏图', '新型冠状病毒感染的肺炎实验室检测技术指南（第三版）', '2003-2010年全国卫生信息化发展纲要', '年报', '住宅金融公库法', '住宅建设计划法', '新能源汽车推广应用推荐车型目录', '万国觉醒', '关于“非典”期间确保新上工程建设顺利开工有关问题的通知', '关于发布2019年（第26批）新认定及全部国家企业技术中心名单的通知', '决战巨神峰', '国家企业技术中心认定管理办法', '关于拟出售控股子公司股权的议案'}
# 机构
# {'碳元科技股份有限公司', '北京中石伟业科技股份有限公司', '深圳市飞荣达科技股份有限公司', '台湾双鸿科技股份有限公司'}

# %% [markdown]
# # 定义NER模型

# %%
class BertCRF(torch.nn.Module):
    def __init__(self, pretrained_bert_model_file_path, num_tags: int, batch_first: bool = False, hidden_size=768):
        super(BertCRF, self).__init__()
        self.bert_module = BertModel.from_pretrained(pretrained_bert_model_file_path)
        self.tag_linear = torch.nn.Linear(hidden_size, num_tags)
        self.crf_module = CRF(num_tags, batch_first)

    def forward(self,
                inputs_ids,
                tags,
                mask = None,
                token_type_ids=None,
                reduction = 'mean'
                ) -> torch.Tensor:
        bert_outputs = self.bert_module.forward(inputs_ids, attention_mask=mask, token_type_ids=token_type_ids)[0]
        bert_outputs = F.dropout(bert_outputs, p=0.2, training=self.training)
        bert_outputs = self.tag_linear(bert_outputs)
        score = -self.crf_module.forward(bert_outputs, tags=tags, mask=mask, reduction=reduction)
        return score

    def decode(self,
               input_ids,
               attention_mask=None,
               token_type_ids=None
               ):
        bert_outputs = self.bert_module.forward(
            input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids
        )[0]
        bert_outputs = self.tag_linear(bert_outputs)
        best_tags_list = self.crf_module.decode(bert_outputs, mask=attention_mask)
        return best_tags_list

# %% [markdown]
# ## 定义NER标签

# %%
chinese_entity_type_vs_english_entity_type = {
    '人物': 'People',
    '行业': 'Industry',
    '业务': 'Business',
    '研报': 'Report',
    '机构': 'Organization',
    '风险': 'Risk',
    '文章': 'Article',
    '指标': 'Indicator',
    '品牌': 'Brand',
    '产品': 'Product'
}
english_entity_type_vs_chinese_entity_type = {v: k for k, v in chinese_entity_type_vs_english_entity_type.items()}

START_TAG = "[CLS]"
END_TAG = "[SEP]"
O = "O"

BPeople = "B-People"
IPeople = "I-People"
BIndustry = "B-Industry"
IIndustry = "I-Industry"
BBusiness = 'B-Business'
IBusiness = 'I-Business'
BProduct = 'B-Product'
IProduct = 'I-Product'
BReport = 'B-Report'
IReport = 'I-Report'
BOrganization = 'B-Organization'
IOrganization = 'I-Organization'
BRisk = 'B-Risk'
IRisk = 'I-Risk'
BArticle = 'B-Article'
IArticle = 'I-Article'
BIndicator = 'B-Indicator'
IIndicator = 'I-Indicator'
BBrand = 'B-Brand'
IBrand = 'I-Brand'

PAD = "[PAD]"
UNK = "[UNK]"
tag2idx = {
    START_TAG: 0,
    END_TAG: 1,
    O: 2,
    BPeople: 3,
    IPeople: 4,
    BIndustry: 5,
    IIndustry: 6,
    BBusiness: 7,
    IBusiness: 8,
    BProduct: 9,
    IProduct: 10,
    BReport: 11,
    IReport: 12,
    BOrganization: 13,
    IOrganization: 14,
    BRisk: 15,
    IRisk: 16,
    BArticle: 17,
    IArticle: 18,
    BIndicator: 19,
    IIndicator: 20,
    BBrand: 21,
    IBrand: 22,
}
tag2id = tag2idx
idx2tag = {v: k for k, v in tag2idx.items()}

# %% [markdown]
# ## 预处理数据函数
#
# `preprocess_data` 函数中的 `for_train` 参数比较重要，指示是否是训练集
#
# 由于给定的训练数据实体部分没有给定出现的位置，这里需要自行查找到实体出现的位置
#
# - 如果是训练集, 按照`entities_json`中的内容在文章中寻找位置并标注, 并将训练数据处理成bio形式
# - 测试数据仅仅做了分句并转化成token id

# %%
class Article:
    def __init__(self, text):
        self._text = text
        self.para_texts = self.split_into_paras(self._text)
        self.sent_texts = [self.split_into_sentence(para) for para in self.para_texts]

    def fix_text(self, text: str) -> str:
        paras = text.split('\n')
        paras = list(filter(lambda para: len(para.strip()) != 0, paras))
        return '\n'.join(paras)

    def split_into_paras(self, text: str):
        paras = list(filter(lambda para: len(para.strip()) != 0, text.split('\n')))
        return paras

    def split_into_sentence(self, one_para_text: str, splited_puncs = None):
        if splited_puncs is None:
            splited_puncs = ['。', '？', '！']
        splited_re_pattern = '[' + ''.join(splited_puncs) + ']'

        para = one_para_text
        sentences = re.split(splited_re_pattern, para)
        sentences = list(filter(lambda sent: len(sent) != 0, sentences))

        return sentences

    def find_sents_by_entity_name(self, entity_text):
        ret_sents = []
        if entity_text not in self._text:
            return []
        else:
            for para in self.split_into_paras(self._text):
                if entity_text not in para:
                    continue
                else:
                    for sent in self.split_into_sentence(para):
                        if entity_text in sent:
                            ret_sents.append(sent)
        return ret_sents

# %%
def _find_all_start_end(source, target):
    if not target:
        return []
    occurs = []
    offset = 0
    while offset < len(source):
        found = source[offset:].find(target)
        if found == -1:
            break
        else:
            occurs.append([offset + found, offset + found + len(target) - 1])
        offset += (found + len(target))
    return occurs

def preprocess_data(entities_json,
                    article_texts,
                    tokenizer: BertTokenizer,
                    for_train: bool = True):
    """
    [{
        'sent': xxx, 'entity_name': yyy, 'entity_type': zzz, 'start_token_id': 0, 'end_token_id': 5,
        'start_index': 0, 'end_index': 2, 
            'sent_tokens': ['token1', 'token2'], 'entity_tokens': ['token3', 'token4']
    }]
    """

    preprocessed_datas = []

    all_sents = []
    for article in tqdm.tqdm([Article(t) for t in article_texts]):
        for para_text in article.para_texts:
            for sent in article.split_into_sentence(para_text):
                sent_tokens = list(sent)
                entity_labels = []
                for entity_type, entities in entities_json.items():
                    for entity_name in entities:
                        if entity_name not in sent:
                            continue
                        all_sents.append(sent)
                        start_end_indexes = _find_all_start_end(sent, entity_name)
                        assert len(start_end_indexes) >= 1
                        for str_start_index, str_end_index in start_end_indexes:
                            entity_tokens = list(entity_name)

                            one_entity_label = {
                                'entity_type': entity_type,
                                'start_token_id': str_start_index,
                                'end_token_id': str_end_index,
                                'start_index': str_start_index,
                                'end_index': str_end_index,
                                'entity_tokens': entity_tokens,
                                'entity_name': entity_name
                            }
                            entity_labels.append(one_entity_label)

                if not entity_labels:
                    tags = [O for _ in range(len(sent_tokens))]
                    tag_ids = [tag2idx[O] for _ in range(len(sent_tokens))]
                    if for_train:
                        continue
                else:
                    tags = []
                    tag_ids = []
                    for sent_token_index in range(len(sent_tokens)):
                        tag = O
                        for entity_label in entity_labels:
                            if sent_token_index == entity_label['start_token_id']:
                                tag = f'B-{chinese_entity_type_vs_english_entity_type[entity_label["entity_type"]]}'
                            elif entity_label['start_token_id'] < sent_token_index < entity_label["end_token_id"]:
                                tag = f'I-{chinese_entity_type_vs_english_entity_type[entity_label["entity_type"]]}'
                        tag_id = tag2idx[tag]
                        tags.append(tag)
                        tag_ids.append(tag_id)
                assert len(sent_tokens) == len(tags) == len(tag_ids)
                not_o_indexes = [index for index, tag in enumerate(tags) if tag != O]
                all_entities = [sent_tokens[index] for index in not_o_indexes]
                all_entities2 = entity_labels

                preprocessed_datas.append({
                    'sent': sent,
                    'sent_tokens': sent_tokens,
                    'sent_token_ids': tokenizer.convert_tokens_to_ids(sent_tokens),
                    'entity_labels': entity_labels,
                    'tags': tags,
                    'tag_ids': tag_ids
                })
    return preprocessed_datas

# %% [markdown]
# # 定义dataset 以及 dataloader

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, preprocessed_datas, tokenizer: BertTokenizer, max_length=512 ):
        self.preprocessed_datas = preprocessed_datas
        self.tokenizer = tokenizer
        self.max_length = max_length

    def pad_sent_ids(self, sent_ids, max_length, padded_token_id):
        mask = [1] * (min(len(sent_ids), max_length)) + [0] * (max_length - len(sent_ids))
        sent_ids = sent_ids[:max_length] + [padded_token_id] * (max_length - len(sent_ids))
        return sent_ids, mask

    def process_one_preprocessed_data(self, preprocessed_data):
        import copy
        preprocessed_data = copy.deepcopy(preprocessed_data)
        
        sent_token_ids = self.tokenizer.convert_tokens_to_ids(
            [START_TAG]) + preprocessed_data['sent_token_ids'] + self.tokenizer.convert_tokens_to_ids([END_TAG])

        sent_token_ids, mask = self.pad_sent_ids(
            sent_token_ids, max_length=self.max_length, padded_token_id=self.tokenizer.pad_token_id)

        sent_token_ids = np.array(sent_token_ids)
        mask = np.array(mask)
        
        preprocessed_data['sent'] = '^' + preprocessed_data['sent'] + '$'
        preprocessed_data['sent_tokens'] = [START_TAG] + preprocessed_data['sent_tokens'] + [END_TAG]
        preprocessed_data['sent_token_ids'] = sent_token_ids
        
        
        tags = [START_TAG] + preprocessed_data['tags'] + [END_TAG]
        tag_ids = [tag2idx[START_TAG]] + preprocessed_data['tag_ids'] + [tag2idx[END_TAG]]
        tag_ids, _ = self.pad_sent_ids(tag_ids, max_length=self.max_length, padded_token_id=tag2idx[O])
        tag_ids = np.array(tag_ids)
        

        for entity_label in preprocessed_data['entity_labels']:
            entity_label['start_token_id'] += 1
            entity_label['end_token_id'] += 1
            entity_label['start_index'] += 1
            entity_label['end_index'] += 1
        
        
        preprocessed_data['tags'] = tags
        preprocessed_data['tag_ids'] = tag_ids

        not_o_indexes = [index for index, tag in enumerate(preprocessed_data['tags']) if tag != O]

        not_o_indexes_str = not_o_indexes
        all_entities = [preprocessed_data['sent_tokens'][index] for index in not_o_indexes]
        all_entities2 = preprocessed_data['entity_labels']
        all_entities3 = [preprocessed_data['sent'][index] for index in not_o_indexes_str]
        
        preprocessed_data.update({'mask': mask})

        return preprocessed_data

    def __getitem__(self, item):
        return self.process_one_preprocessed_data(
            self.preprocessed_datas[item]
        )

    def __len__(self):
        return len(self.preprocessed_datas)


def custom_collate_fn(data):
    # copy from torch official，无需深究
    from torch._six import container_abcs, string_classes

    r"""Converts each NumPy array data field into a tensor"""
    np_str_obj_array_pattern = re.compile(r'[SaUO]')
    elem_type = type(data)
    if isinstance(data, torch.Tensor):
        return data
    elif elem_type.__module__ == 'numpy' and elem_type.__name__ != 'str_' and elem_type.__name__ != 'string_':
        # array of string classes and object
        if elem_type.__name__ == 'ndarray' and np_str_obj_array_pattern.search(data.dtype.str) is not None:
            return data
        return torch.as_tensor(data)
    elif isinstance(data, container_abcs.Mapping):
        tmp_dict = {}
        for key in data:
            if key in ['sent_token_ids', 'tag_ids', 'mask']:
                tmp_dict[key] = custom_collate_fn(data[key])
                if key == 'mask':
                    tmp_dict[key] = tmp_dict[key].byte()
            else:
                tmp_dict[key] = data[key]
        return tmp_dict
    elif isinstance(data, tuple) and hasattr(data, '_fields'):  # namedtuple
        return elem_type(*(custom_collate_fn(d) for d in data))
    elif isinstance(data, container_abcs.Sequence) and not isinstance(data, string_classes):
        return [custom_collate_fn(d) for d in data]
    else:
        return data


def build_dataloader(preprocessed_datas, tokenizer: BertTokenizer, batch_size=32, shuffle=True):
    dataset = MyDataset(preprocessed_datas, tokenizer)
    import torch.utils.data
    dataloader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, collate_fn=custom_collate_fn, shuffle=shuffle)
    return dataloader

# %% [markdown]
# # 定义训练时评价指标
#
# 仅供训练时参考, 包含实体的precision，recall以及f1。
#
# 只有和标注的数据完全相同才算是1，否则为0

# %%
# 训练时指标
class EvaluateScores:
    def __init__(self, entities_json, predict_entities_json):
        self.entities_json = entities_json
        self.predict_entities_json = predict_entities_json

    def compute_entities_score(self):
        return evaluate_entities(self.entities_json, self.predict_entities_json, list(set(self.entities_json.keys())))
    
def _compute_metrics(ytrue, ypred):
    ytrue = set(ytrue)
    ypred = set(ypred)
    tr = len(ytrue)
    pr = len(ypred)
    hit = len(ypred.intersection(ytrue))
    p = hit / pr if pr!=0 else 0
    r = hit / tr if tr!=0 else 0
    f1 = 2 * p * r / (p + r) if (p+r)!=0 else 0
    return {
        'p': p,
        'r': r,
        'f': f1,
    }


def evaluate_entities(true_entities, pred_entities, entity_types):
    scores = []

    ps2 = []
    rs2 = []
    fs2 = []
    
    for ent_type in entity_types:

        true_entities_list = true_entities.get(ent_type, [])
        pred_entities_list = pred_entities.get(ent_type, [])
        s = _compute_metrics(true_entities_list, pred_entities_list)
        scores.append(s)
    ps = [i['p'] for i in scores]
    rs = [i['r'] for i in scores]
    fs = [i['f'] for i in scores]
    s = {
        'p': sum(ps) / len(ps),
        'r': sum(rs) / len(rs),
        'f': sum(fs) / len(fs),
    }
    return s

# %% [markdown]
# ## 定义ner train loop， evaluate loop ，test loop

# %%
def train(model: BertCRF, optimizer, data_loader: torch.utils.data.DataLoader, logger: logging.Logger, epoch_id,
          device='cpu'):
    pbar = tqdm.tqdm(data_loader)
    for batch_id, one_data in enumerate(pbar):
        model.train()

        sent_token_ids = torch.stack([d['sent_token_ids'] for d in one_data]).to(device)
        tag_ids = torch.stack([d['tag_ids'] for d in one_data]).to(device)
        mask = torch.stack([d['mask'] for d in one_data]).to(device)

        loss = model.forward(sent_token_ids, tag_ids, mask)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        pbar.set_description('epoch: {}, loss: {:.3f}'.format(epoch_id, loss.item()))


def evaluate(
        model, data_loader: torch.utils.data.DataLoader, logger: logging.Logger,
        tokenizer, device='cpu',
):
    founded_entities_json = defaultdict(set)
    golden_entities_json = defaultdict(set)
    for batch_id, one_data in enumerate(data_loader):
        model.eval()
        sent_token_ids = torch.stack([d['sent_token_ids'] for d in one_data]).to(device)
        tag_ids = torch.stack([d['tag_ids'] for d in one_data]).to(device)
        mask = torch.stack([d['mask'] for d in one_data]).to(device)

        best_tag_ids_list = model.decode(sent_token_ids, attention_mask=mask)
        best_tags_list = [[idx2tag[idx] for idx in idxs] for idxs in best_tag_ids_list]

        for data, best_tags in zip(one_data, best_tag_ids_list):

            for entity_label in data['entity_labels']:
                golden_entities_json[entity_label['entity_type']].add(entity_label['entity_name'])

            record = False
            for token_index, tag_id in enumerate(best_tags):
                tag = idx2tag[tag_id]
                if tag.startswith('B'):
                    start_token_index = token_index
                    entity_type = tag[2:]
                    record = True
                elif record and tag == O:
                    end_token_index = token_index

                    str_start_index = start_token_index
                    str_end_index = end_token_index

                    entity_name = data['sent'][str_start_index: str_end_index]

                    entity_type = english_entity_type_vs_chinese_entity_type[entity_type]
                    founded_entities_json[entity_type].add(entity_name)
                    record = False
    evaluate_tool = EvaluateScores(golden_entities_json, founded_entities_json)
    scores = evaluate_tool.compute_entities_score()
    return scores['f']


def test(model, data_loader: torch.utils.data.DataLoader, logger: logging.Logger, device):
    founded_entities = []
    for batch_id, one_data in enumerate(tqdm.tqdm(data_loader)):
        model.eval()
        sent_token_ids = torch.stack([d['sent_token_ids'] for d in one_data]).to(device)
        mask = torch.stack([d['mask'] for d in one_data]).to(device)

        with torch.no_grad():
            best_tag_ids_list = model.decode(sent_token_ids, attention_mask=mask, token_type_ids=None)

        for data, best_tags in zip(one_data, best_tag_ids_list):
            record = False
            for token_index, tag_id in enumerate(best_tags):
                tag = idx2tag[tag_id]
                if tag.startswith('B'):
                    start_token_index = token_index
                    entity_type = tag[2:]
                    record = True
                elif record and tag == O:
                    end_token_index = token_index
                    entity_name = data['sent_tokens'][start_token_index: end_token_index + 1]
                    founded_entities.append((entity_name, entity_type, data['sent']))
                    record = False
    result = defaultdict(list)
    for entity_name, entity_type, sent in founded_entities:
        entity = ''.join(entity_name).replace('##', '')
        entity = entity.replace('[CLS]', '')
        entity = entity.replace('[UNK]', '')
        entity = entity.replace('[SEP]', '')
        if len(entity) > 1:
            result[english_entity_type_vs_chinese_entity_type[entity_type]].append((entity, sent))

    for ent_type, ents in result.items():
        result[ent_type] = list(set(ents))
    return result

# %% [markdown]
# # ner主要训练流程
#
# - 分隔训练集验证集，并处理成dataset dataloader
# - 训练，验证，保存模型

# %%
def main_train(logger, tokenizer, model, to_be_trained_entities, yanbao_texts):
    entities_json = to_be_trained_entities
    train_entities_json = {k: [] for k in entities_json}
    dev_entities_json = {k: [] for k in entities_json}

    train_proportion = 0.9
    for entity_type, entities in entities_json.items():
        entities = entities.copy()
        random.shuffle(entities)
        
        train_entities_json[entity_type] = entities[: int(len(entities) * train_proportion)]
        dev_entities_json[entity_type] = entities[int(len(entities) * train_proportion):]

    
    train_preprocessed_datas = preprocess_data(train_entities_json, yanbao_texts, tokenizer)
    train_dataloader = build_dataloader(train_preprocessed_datas, tokenizer, batch_size=BATCH_SIZE)
    
    dev_preprocessed_datas = preprocess_data(dev_entities_json, yanbao_texts, tokenizer)
    dev_dataloader = build_dataloader(dev_preprocessed_datas, tokenizer, batch_size=BATCH_SIZE)

    model = model.to(DEVICE)
    for name, param in model.named_parameters():
        if "bert_module" in name:
            param.requires_grad = False
        else:
            param.requires_grad = True
    optimizer = torch.optim.Adam([para for para in model.parameters() if para.requires_grad],
                                 lr=0.001,
                                 weight_decay=0.0005)
    best_evaluate_score = 0
    for epoch in range(TOTAL_EPOCH_NUMS):
        train(model, optimizer, train_dataloader, logger=logger, epoch_id=epoch, device=DEVICE)
        evaluate_score = evaluate(model, dev_dataloader, logger=logger, tokenizer=tokenizer, device=DEVICE)
        print('评估分数：', evaluate_score)
        if evaluate_score >= best_evaluate_score:
            best_evaluate_score = evaluate_score
            save_model_path = os.path.join(SAVE_MODEL_DIR, 'finnal_ccks_model.pth')
            logger.info('saving model to {}'.format(save_model_path))
            torch.save(model.cpu().state_dict(), save_model_path)
            model.to(DEVICE)

# %% [markdown]
# ## 准备训练ner模型

# %%
logger = logging.getLogger(__name__)

tokenizer = BertTokenizer.from_pretrained(
    os.path.join(PRETRAINED_BERT_MODEL_DIR, 'vocab.txt')
)

model = BertCRF(
    pretrained_bert_model_file_path=PRETRAINED_BERT_MODEL_DIR,
    num_tags=len(tag2id), batch_first=True
)

save_model_path = os.path.join(SAVE_MODEL_DIR, 'finnal_ccks_model.pth')
if Path(save_model_path).exists():
    model_state_dict = torch.load(save_model_path, map_location='cpu')
    model.load_state_dict(model_state_dict)

# %%
# 训练数据在main_train函数中处理并生成dataset dataloader，此处无需生成

# 测试数据在此处处理并生成dataset dataloader
test_preprocessed_datas = preprocess_data({}, yanbao_texts, tokenizer, for_train=False)
test_dataloader = build_dataloader(test_preprocessed_datas, tokenizer, batch_size=BATCH_SIZE)
# Out:
# 100%|██████████| 200/200 [00:01<00:00, 130.76it/s]

# %% [markdown]
# ## 整个训练流程是：
#
# - 使用数据集增强得到更多的实体
# - 使用增强过后的实体来指导训练
#
#
# - 训练后的模型重新对所有文档中进行预测，得到新的实体，加入到实体数据集中
# - 使用扩增后的实体数据集来进行二次训练，再得到新的实体，再增强实体数据集
# - (模型预测出来的数据需要`review_model_predict_entities`后处理形成提交格式)
#
#
# - 如果提交结果，需要`extract_entities`函数删除提交数据中那些出现在训练数据中的实体

# %% [markdown]
# ### 模型预测结果后处理函数
#
# - `review_model_predict_entities`函数将模型预测结果后处理，从而生成提交文件格式

# %%
def review_model_predict_entities(model_predict_entities):
    word_tag_map = POSTokenizer().word_tag_tab
    idf_freq = TFIDF().idf_freq
    reviewed_entities = defaultdict(list)
    for ent_type, ent_and_sent_list in model_predict_entities.items():
        for ent, sent in ent_and_sent_list:
            start = sent.lower().find(ent)
            if start == -1:
                continue
            start += 1
            end = start + len(ent) - 1
            tokens = jieba.lcut(sent)
            offset = 0
            selected_tokens = []
            for token in tokens:
                offset += len(token)
                if offset >= start:
                    selected_tokens.append(token)
                if offset >= end:
                    break

            fixed_entity = ''.join(selected_tokens)
            fixed_entity = re.sub(r'\d*\.?\d+%$', '', fixed_entity)
            if ent_type == '人物':
                if len(fixed_entity) >= 10:
                    continue
            if len(fixed_entity) <= 1:
                continue
            if re.findall(r'^\d+$', fixed_entity):
                continue
            if word_tag_map.get(fixed_entity, '') == 'v' and idf_freq[fixed_entity] < 7:
                continue
            reviewed_entities[ent_type].append(fixed_entity)
    return reviewed_entities

# %% [markdown]
# - `extract_entities` 删除与训练集中重复的实体

# %%
def extract_entities(to_be_trained_entities):
    test_entities = to_be_trained_entities
    train_entities = read_json(Path(DATA_DIR, 'entities.json'))

    for ent_type, ents in test_entities.items():
        test_entities[ent_type] = list(set(ents) - set(train_entities[ent_type]))

    for ent_type in train_entities.keys():
        if ent_type not in test_entities:
            test_entities[ent_type] = []
    return test_entities

# %%
# 循环轮次数目
nums_round = 2
for i in range(nums_round):
    # train
    main_train(logger, tokenizer, model, to_be_trained_entities, yanbao_texts)        
    
    model = model.to(DEVICE)
    model_predict_entities = test(model, test_dataloader, logger=logger, device=DEVICE)
    
    # 修复训练预测结果
    reviewed_entities = review_model_predict_entities(model_predict_entities)
    
    # 将训练预测结果再次放入训练集中， 重新训练或者直接出结果
    for ent_type, ents in reviewed_entities.items():
        to_be_trained_entities[ent_type] = list(set(to_be_trained_entities[ent_type] + ents))

# 创造出提交结果
submit_entities = extract_entities(to_be_trained_entities)
# Out:
# 100%|██████████| 200/200 [00:06<00:00, 32.99it/s]
# 100%|██████████| 200/200 [00:00<00:00, 278.84it/s]
# epoch: 0, loss: 10.970: 100%|██████████| 217/217 [06:16<00:00,  1.74s/it]
# epoch: 1, loss: 9.987: 100%|██████████| 217/217 [06:12<00:00,  1.71s/it]
# epoch: 2, loss: 10.875: 100%|██████████| 217/217 [06:20<00:00,  1.75s/it]
# epoch: 3, loss: 9.552: 100%|██████████| 217/217 [06:13<00:00,  1.72s/it]
# epoch: 4, loss: 7.684: 100%|██████████| 217/217 [06:17<00:00,  1.74s/it]
# epoch: 5, loss: 6.956: 100%|██████████| 217/217 [06:04<00:00,  1.68s/it]
# epoch: 6, loss: 8.992: 100%|██████████| 217/217 [06:11<00:00,  1.71s/it]
# epoch: 7, loss: 8.051: 100%|██████████| 217/217 [06:12<00:00,  1.72s/it]
# epoch: 8, loss: 6.158: 100%|██████████| 217/217 [06:16<00:00,  1.73s/it]
# epoch: 9, loss: 7.391: 100%|██████████| 217/217 [06:11<00:00,  1.71s/it]
# 100%|██████████| 349/349 [04:29<00:00,  1.29it/s]
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 1.091 seconds.
# Prefix dict has been built successfully.
# 100%|██████████| 200/200 [00:07<00:00, 25.16it/s]
# 100%|██████████| 200/200 [00:01<00:00, 124.40it/s]
# epoch: 0, loss: 7.931: 100%|██████████| 242/242 [06:55<00:00,  1.72s/it]
# epoch: 1, loss: 6.872: 100%|██████████| 242/242 [06:57<00:00,  1.73s/it]
# epoch: 2, loss: 9.052: 100%|██████████| 242/242 [06:56<00:00,  1.72s/it]
# epoch: 3, loss: 5.383: 100%|██████████| 242/242 [06:58<00:00,  1.73s/it]
# epoch: 4, loss: 5.044: 100%|██████████| 242/242 [06:53<00:00,  1.71s/it]
# epoch: 5, loss: 7.522: 100%|██████████| 242/242 [06:57<00:00,  1.73s/it]
# epoch: 6, loss: 6.433: 100%|██████████| 242/242 [06:59<00:00,  1.73s/it]
# epoch: 7, loss: 7.924: 100%|██████████| 242/242 [06:56<00:00,  1.72s/it]
# epoch: 8, loss: 4.678: 100%|██████████| 242/242 [07:00<00:00,  1.74s/it]
# epoch: 9, loss: 8.775: 100%|██████████| 242/242 [06:56<00:00,  1.72s/it]
# 100%|██████████| 349/349 [04:27<00:00,  1.31it/s]

# %% [markdown]
# # 属性抽取
#
# 通过规则抽取属性
#
# - 研报时间
# - 研报评级
# - 文章时间

# %%
def find_article_time(yanbao_txt, entity):
    str_start_index = yanbao_txt.index(entity)
    str_end_index = str_start_index + len(entity)
    para_start_index = yanbao_txt.rindex('\n', 0, str_start_index)
    para_end_index = yanbao_txt.index('\n', str_end_index)

    para = yanbao_txt[para_start_index + 1: para_end_index].strip()
    if len(entity) > 5:
        ret = re.findall(r'(\d{4})\s*[年-]\s*(\d{1,2})\s*[月-]\s*(\d{1,2})\s*日?', para)
        if ret:
            year, month, day = ret[0]
            time = '{}/{}/{}'.format(year, month.lstrip(), day.lstrip())
            return time

    start_index = 0
    time = None
    min_gap = float('inf')
    for word, poseg in pseg.cut(para):
        if poseg in ['t', 'TIME'] and str_start_index <= start_index < str_end_index:
            gap = abs(start_index - (str_start_index + str_end_index) // 2)
            if gap < min_gap:
                min_gap = gap
                time = word
        start_index += len(word)
    return time


def find_yanbao_time(yanbao_txt, entity):
    paras = [para.strip() for para in yanbao_txt.split('\n') if para.strip()][:5]
    for para in paras:
        ret = re.findall(r'(\d{4})\s*[\./年-]\s*(\d{1,2})\s*[\./月-]\s*(\d{1,2})\s*日?', para)
        if ret:
            year, month, day = ret[0]
            time = '{}/{}/{}'.format(year, month.lstrip(), day.lstrip())
            return time
    return None

# %%
def extract_attrs(entities_json):
    train_attrs = read_json(Path(DATA_DIR, 'attrs.json'))['attrs']

    seen_pingjis = []
    for attr in train_attrs:
        if attr[1] == '评级':
            seen_pingjis.append(attr[2])
    article_entities = entities_json.get('文章', [])
    yanbao_entities = entities_json.get('研报', [])

    attrs_json = []
    for file_path in tqdm.tqdm(list(Path(DATA_DIR, 'yanbao_txt').glob('*.txt'))):
        yanbao_txt = '\n' + Path(file_path).open().read() + '\n'
        for entity in article_entities:
            if entity not in yanbao_txt:
                continue
            time = find_article_time(yanbao_txt, entity)
            if time:
                attrs_json.append([entity, '发布时间', time])

        yanbao_txt = '\n'.join(
            [para.strip() for para in yanbao_txt.split('\n') if
             len(para.strip()) != 0])
        for entity in yanbao_entities:
            if entity not in yanbao_txt:
                continue

            paras = yanbao_txt.split('\n')
            for para_id, para in enumerate(paras):
                if entity in para:
                    break

            paras = paras[: para_id + 5]
            for para in paras:
                for pingji in seen_pingjis:
                    if pingji in para:
                        if '上次' in para:
                            attrs_json.append([entity, '上次评级', pingji])
                            continue
                        elif '维持' in para:
                            attrs_json.append([entity, '上次评级', pingji])
                        attrs_json.append([entity, '评级', pingji])

            time = find_yanbao_time(yanbao_txt, entity)
            if time:
                attrs_json.append([entity, '发布时间', time])
    attrs_json = list(set(tuple(_) for _ in attrs_json) - set(tuple(_) for _ in train_attrs))
    
    return attrs_json

# %%
train_attrs = read_json(Path(DATA_DIR, 'attrs.json'))['attrs']
submit_attrs = extract_attrs(submit_entities)
# Out:
# 100%|██████████| 200/200 [00:04<00:00, 48.19it/s]

# %%
submit_attrs
# Out:
# [('新消费&新零售', '发布时间', '2020/02/13'),
#  ('4季度中场业务仍然有所增长', '发布时间', '2020/02/07'),
#  ('各地政策放松及货币财政发力点评', '发布时间', '2020/02/26'),
#  ('证券研究报告/行业深度报告证券研究报告/行业深度报告', '发布时间', '2020/2/6'),
#  ('证券研究报告·行业研究·文化传媒', '发布时间', '2020/01/14'),
#  ('IECQ符合性证书有害物质过程管理', '发布时间', '2020/1/9'),
#  ('行业投资风险', '上次评级', '买入'),
#  ('公司深度研究|食品、饮料与烟草', '评级', '买入'),
#  ('乘用车企业平均燃料消耗量与新能源汽车积分并行管理办
),
#  ('中国飞鹤：正式纳入港股通，积极应对疫情保障正常运营，品牌力和竞争优势进一步强化', '发布时间', '2020/02/22'),
#  ('持续改善中的电动车龙头', '发布时间', '2020/02/10'),
#  ('复苏之路', '发布时间', '2020/02/02'),
#  ('锂电铜箔：深蹲', '发布时间', '2020/2/6'),
#  ('消失的需求，创造的消费，递延的社交——从需求类别看疫情对食品饮料行业的影响', '发布时间', '2020/02/18'),
#  ('羊奶粉龙头，业绩增长', '发布时间', '2020/02/27'),
#  ('投资建议', '发布时间', '2020/1/4'),
#  ('投资建议：疫情影响消退，把握券商银行', '评级', '推荐'),
#  ('光伏设备行业报告：PERC 持续高景气,大尺寸及 HJT 引领设备迭代', '发布时间', '2020/02/19'),
#  ('行业评级', '发布时间', '2020/02/16'),
#  ('估值与投资评级', '评级', '买入'),
#  ('西北菜&酸菜鱼龙头，规模化扩张与品质化提升并举', '发布时间', '2020/01/16'),
#  ('集中回购，彰显投资价值', '上次评级', '买入'),
#  ('推荐（首次）风险评级：中风险', '发布时间', '2020/2/6'),
#  ('关于推动银行业', '发布时间', '2020/1/4'),
#  ('推荐 维持评级', '评级', '推荐'),
#  ('中华人民共和国政府和美利坚合众国政府经济贸易协议', '发布时间', '2020/1/15'),
#  ('美股研究框架及走势展望', '发布时间', '2019/8/18'),
#  ('行情回顾', '发布时间', '2020/01/20'),
#  ('证券研究报告', '上次评级', '增持'),
#  ('行业研究/机械工业', '上次评级', '优于大市'),
#  ('推荐（首次）风险评级：中风险', '评级', '推荐'),
#  ('证券研究报告/行业动态报告', '评级', '优于大势'),
#  ('评级：买入上次评级：买入', '上次评级', '买入'),
#  ('新的起点，从5G看云', '发布时间', '2008/10/28'),
#  ('借助海上作业优势，布局海上风电项目', '发布时间', '2019/6/10'),
#  ('城堡争霸：曙光大陆》', '发布时间', '2019/1/6'),
#  ('本轮半导体行情的四个逻辑', '发布时间', '2020/03/02'),
#  ('新冠疫情医药行业专题报告', '评级', '推荐'),
#  ('一城一策持续放松，货币财政双双发力', '发布时间', '2020/02/26'),
#  ('半导体业务孕育巨大机会，业务', '上次评级', '增持'),
#  ('部分产能过剩行业产能置换实施办法', '发布时间', '2021/1/1'),
#  ('投资建议', '发布时间', '2020/01/14'),
#  ('新消费&新零售', '上次评级', '买入'),
#  ('受疫情影响相对较小，短期车险赔付率有望改善', '评级', '买入'),
#  ('投资建议', '上次评级', '增持'),
#  ('粮价波动与猪周期', '发布时间', '2019/12/18'),
#  ('证券研究报告', '发布时间', '2020/2/6'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '发布时间', '2019/12/18'),
#  ('投资建议', '评级', '优于大市'),
#  ('从SARS疫情复盘看新型冠状病毒肺炎对机械行业的影响', '上次评级', '优于大市'),
#  ('十三五”国家战略性新兴产业发展规划', '发布时间', '2016/11/29'),
#  ('聚焦中小客户分散风险', '评级', '推荐'),
#  ('证券研究报告|行业投资策略报告', '发布时间', '2020/02/26'),
#  ('人才寻访：高毛利业务，量价双增促成长', '评级', '推荐'),
#  ('投资建议', '评级', '买入'),
#  ('强强联合，共拓带电操作机器人百亿蓝海市场', '上次评级', '增持'),
#  ('中国制造等》', '发布时间', '2016/11/29'),
#  ('评级 买入', '发布时间', '2019/12/18'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '评级', '买入'),
#  ('估值与投资评级', '上次评级', '买入'),
#  ('社融超预期，把握行情机会', '上次评级', '推荐'),
#  ('行业评级', '发布时间', '2020/02/25'),
#  ('集中回购，彰显投资价值', '发布时间', '2020/2/25'),
#  ('深度跟踪报告', '上次评级', '买入'),
#  ('危废垃圾双轮驱动，政策利好助力成长',
),
#  ('重构新消费：社交资产如何链接“品”与“效”', '发布时间', '2020/02/05'),
#  ('证券研究报告/行业动态报告', '上次评级', '优于大势'),
#  ('手机产业系列报告之二', '发布时间', '2020/2/5'),
#  ('拳头', '评级', '买入'),
#  ('特斯拉专题系列报告（一）：', '发布时间', '2020/02/09'),
#  ('借助海上作业优势，布局海上风电项目', '评级', '优于大市'),
#  ('新冠疫情医药行业专题报告', '发布时间', '2002/12/15'),
#  ('报告摘要：', '评级', '推荐'),
#  ('寿险销售的逆周期性与投资的稳定性', '发布时间', '2020/1/4'),
#  ('半导体业务孕育巨大机会，业务', '评级', '增持'),
#  ('证券研究报告/行业深度报告', '发布时间', '2020/2/6'),
#  ('19 年 Q4 业绩胜预期；公司业务具韧性', '评级', '增持'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '上次评级', '推荐'),
#  ('轻资产', '评级', '推荐'),
#  ('行业研究┃专题报告', '发布时间', '2020/2/14'),
#  ('国产化', '上次评级', '增持'),
#  ('投资建议', '发布时间', '2020/2/14'),
#  ('报告摘要：', '上次评级', '推荐'),
#  ('关于使用部分闲置募集资金暂时补充流动资金的议案', '发布时间', '2019/4/7'),
#  ('国产化', '发布时间', '2020/02/10'),
#  ('跟随大市', '发布时间', '2020/02/10'),
#  ('创新人力资源领导者，灵活用工驱动高成长', '发布时间', '2020/01/16'),
#  ('公司深度研究|食品、饮料与烟草', '发布时间', '2020/02/27'),
#  ('估值与投资建议', '评级', '买入'),
#  ('关于做好地方政府专项债券发行及项目配套融资工作的通知', '发布时间', '2019/6/10'),
#  ('携手“鲲鹏”，展翅入“云', '发布时间', '2020/02/14'),
#  ('投资建议：疫情影响消退，把握券商银行', '上次评级', '推荐'),
#  ('评级：买入上次评级：买入', '发布时间', '2020/02/13'),
#  ('行业评级强于大市(维持评级', '发布时间', '2020/02/18'),
#  ('行业评级强于大市(维持评级)上次评级强于大市', '发布时间', '2020/01/15'),
#  ('他山之石，从龟甲万、味好美看调味品公司发展路径', '上次评级', '优于大势'),
#  ('投资建议', '发布时间', '2020/02/21'),
#  ('国产化', '发布时间', '2020/03/02'),
#  ('关于建设欧洲生产', '发布时间', '2018/7/9'),
#  ('新型肺炎影响显著，短期需关注事态发展', '发布时间', '2020/2/12'),
#  ('国产化', '发布时间', '2020/2/6'),
#  ('公司深度研究|医疗保健', '发布时间', '2020/01/17'),
#  ('推荐 维持评级', '上次评级', '推荐'),
#  ('游戏强劲，在线教育迎风起航', '评级', '买入'),
#  ('拳头游戏下行，静待新游接棒', '上次评级', '买入'),
#  ('行业评级强于大市(维持评级', '发布时间', '2020/01/15'),
#  ('证券研究报告|行业周报', '上次评级', '增持'),
#  ('疫情冲击旅游业既定预期，短期业绩承压，静候细分龙头复苏', '上次评级', '推荐'),
#  ('公告点评|耐用消费品与服装', '评级', '买入'),
#  ('行业评级', '发布时间', '2020/01/15'),
#  ('拳头', '上次评级', '买入'),
#  ('羊奶粉龙头，业绩增长', '评级', '买入'),
#  ('证券研究报告', '评级', '优于大势'),
#  ('风险因素', '评级', '买入'),
#  ('投资建议', '上次评级', '推荐'),
#  ('手机产业系列报告之二', '上次评级', '推荐'),
#  ('国产化', '发布时间', '2020/02/19'),
#  ('投资建议', '发布时间', '2020/02/13'),
#  ('迈过泥泞，方成涅槃——短期影响不改行
),
#  ('有危才有机，疫情扰动不影响中长期成长逻辑', '上次评级', '买入'),
#  ('投资建议', '评级', '增持'),
#  ('新的起点，从5G看云', '发布时间', '2019/12/18'),
#  ('“十三五”国家战略性新兴产业发展规划', '发布时间', '2016/11/29'),
#  ('携手“鲲鹏”，展翅入“云', '评级', '买入'),
#  ('从FILA到Amer，新起点与新征程', '评级', '买入')]

# %% [markdown]
# # 关系抽取
#
# - 对于研报实体，整个文档抽取特定类型(行业，机构，指标)的关系实体
# - 其他的实体仅考虑与其出现在同一句话中的其他实体组织成特定关系

# %%
def extract_relations(schema, entities_json):
    relation_by_rules = []
    relation_schema = schema['relationships']
    unique_s_o_types = []
    so_type_cnt = defaultdict(int)
    for s_type, p, o_type in schema['relationships']:
        so_type_cnt[(s_type, o_type)] += 1
    for (s_type, o_type), cnt in so_type_cnt.items():
        if cnt == 1 and s_type != o_type:
            unique_s_o_types.append((s_type, o_type))

    for path in tqdm.tqdm(list(Path(DATA_DIR, 'yanbao_txt').glob('*.txt'))):
        with open(path) as f:
            entity_dict_in_file = defaultdict(lambda: defaultdict(list))
            main_org = None
            for line_idx, line in enumerate(f.readlines()):
                for sent_idx, sent in enumerate(split_to_sents(line)):
                    for ent_type, ents in entities_json.items():
                        for ent in ents:
                            if ent in sent:
                                if ent_type == '机构' and len(line) - len(ent) < 3 or \
                                        re.findall('[\(（]\d+\.*[A-Z]*[\)）]', line):
                                    main_org = ent
                                else:
                                    if main_org and '客户' in sent:
                                        relation_by_rules.append([ent, '客户', main_org])
                                entity_dict_in_file[ent_type][
                                    ('test', ent)].append(
                                    [line_idx, sent_idx, sent,
                                     sent.find(ent)]
                                )

            for s_type, p, o_type in relation_schema:
                s_ents = entity_dict_in_file[s_type]
                o_ents = entity_dict_in_file[o_type]
                if o_type == '业务' and not '业务' in line:
                    continue
                if o_type == '行业' and not '行业' in line:
                    continue
                if o_type == '文章' and not ('《' in line or not '》' in line):
                    continue
                if s_ents and o_ents:
                    for (s_ent_src, s_ent), (o_ent_src, o_ent) in product(s_ents, o_ents):
                        if s_ent != o_ent:
                            s_occs = [tuple(_[:2]) for _ in
                                      s_ents[(s_ent_src, s_ent)]]
                            o_occs = [tuple(_[:2]) for _ in
                                      o_ents[(o_ent_src, o_ent)]]
                            intersection = set(s_occs) & set(o_occs)
                            if s_type == '研报' and s_ent_src == 'test':
                                relation_by_rules.append([s_ent, p, o_ent])
                                continue
                            if not intersection:
                                continue
                            if (s_type, o_type) in unique_s_o_types and s_ent_src == 'test':
                                relation_by_rules.append([s_ent, p, o_ent])

    train_relations = read_json(Path(DATA_DIR, 'relationships.json'))['relationships']
    result_relations_set = list(set(tuple(_) for _ in relation_by_rules) - set(tuple(_) for _ in train_relations))
    return result_relations_set

# %%
schema = read_json(Path(DATA_DIR, 'schema.json'))
submit_relations  = extract_relations(schema, submit_entities)
# Out:
# 100%|██████████| 200/200 [00:13<00:00, 15.10it/s]

# %%
submit_relations
# Out:
# [('银保监会', '发布', '关于推动银行业和保险业高质量发展的指导意见'),
#  ('国知', '发布', '商标案件请示的批复'),
#  ('2019年业绩前瞻：稳健增长的一年', '涉及', '韩国'),
#  ('手机产业系列报告之二', '涉及', 'DELL'),
#  ('2019年业绩前瞻：稳健增长的一年', '涉及', '天猫'),
#  ('新能源汽车销量', '拥有', '新能源汽车销量不及预期'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '国鸿氢能电堆'),
#  ('京运通', '发布', '关于出售资产的进展公告'),
#  ('深圳市禾望电气股份有限公司', '发布', '公告'),
#  ('党组', '发布', '协议'),
#  ('继续深挖低线城市业务发展机会', '涉及', '中国'),
#  ('各类传感器有望', '涉及', '新能源汽车销量'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '贵研铂业'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '中南大学'),
#  ('迈过泥泞，方成涅槃——短期影响不改行业', '涉及', '中国'),
#  ('投资建议：疫情影响消退，把握券商银行', '涉及', '人行发布'),
#  ('中环', '发布', '关于'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', 'Gigafactory1工厂'),
#  ('半导体行情的风险是什么', '涉及', 'spansion'),
#  ('迈过泥泞，方成涅槃——短期影响不改行业', '涉及', '锦江'),
#  ('科技', '客户', '北京中石伟业科技股份有限公司'),
#  ('投资建议', '涉及', '印度'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '开元物业'),
#  ('基建', '拥有', '基建/地产投资增速下滑'),
#  ('半导体业务孕育巨大机会，业务', '涉及', '国盛证券'),
#  ('半导体行情的风险是什么', '涉及', '美的'),
#  ('投资建议', '涉及', '国鸿氢能电堆'),
#  ('证券研究报告/行业深度报告', '涉及', '动力电池'),
#  ('高精度地图有望迎来成长拐点', '涉及', '日本'),
#  ('卓越的能耗', '涉及', '蔚来汽车'),
#  ('山东电力交易中心', '发布', '公告'),
#  ('国际学校', '开展', '教育'),
#  ('公司教育', '开展', '在线教育'),
#  ('证券研究报告', '涉及', '新能源汽车积分并行管理办法》的决定（征求意见稿'),
#  ('公司深度研究|食品、饮料与烟草', '涉及', '协会'),
#  ('深度产业运营+投资，健康、快乐、富足生态步入收获期', '涉及', '国药控股'),
#  ('深圳图书馆', '开展', '交通'),
#  ('英威腾', '发布', '关于2015年第二期限制性股票激励计划预留部分第三个解锁期符合条件的议案'),
#  ('报告摘要：', '涉及', '安徽省电力有限公司'),
#  ('游戏强劲，在线教育迎风起航', '涉及', '上达'),
#  ('行业评级', '涉及', '能源汽车'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '捷威'),
#  ('集团地产', '开展', '物业项目'),
#  ('国产化', '涉及', '瑞典OPCONAB公司'),
#  ('通威股份有限公司', '发布', '关于'),
#  ('疫情冲击旅游业既定预期，短期业绩承压，静候细分龙头复苏', '涉及', '2018'),
#  ('投资建议', '涉及', '博腾股份'),
#  ('高精度地图有望迎来成长拐点', '涉及', '意法半导体'),
#  ('公司深度研究|医疗保健', '涉及', 'ART'),
#  ('物业管理', '发布', '计划'),
#  ('生殖中心', '开展', '人员培训'),
#  ('政府', '发布', '住宅公营法'),
#  ('科技', '开展', '信息技术'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '东丽'),
#  ('大消费联合系列报告：不可忽视的刚需消费', '涉及', '双汇作为'),
#  ('九毛', '拥有', '家九毛九'),
#  ('行业评级', '涉及', '新能源汽车推广不及预期'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '隆基股份'),
#  ('小美', '发布', '弓箭手大作战》'),
#  ('鸡蛋煎饼', '拥有', '九毛九十年'),
#  ('零售', '发布', '方案'),
#  ('国产化', '涉及', '深圳'),
#  ('国产', '发布', '计划'),
#  ('证券研究报告/行业深度报告', '采用', '复合增长'),
#  ('轻资产', '涉及', '太平'),
#  ('Wi-Fi6：拐点已至', '涉及', '乐鑫科技'),
#  ('国产化', '涉及', '日本东丽'),
#  ('投资建议', '涉及', '怂及那未大叔'),
#  ('欧美', '拥有', '食品安全'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '新城悦服务'),
#  ('粮食会是明年', '涉及', '江淮'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '涉及', '健康'),
#  ('报告摘要：', '涉及', '诺德投资'),
#  ('行业评级强于大市(维持评级', '涉及', '保险公司'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '6）产业园'),
#  ('证券研究报告/行业深度报告证券研究报告/行业深度报告', '涉及', '新能源车'),
#  ('证券研究报告', '涉及', '国家'),
#  ('证券研究报告/行业深度报告', '涉及', 'Model'),
#  ('估值与投资建议', '涉及', '锦欣于'),
#  ('一城一策持续放松，货币财政', '涉及', '工商'),
#  ('春鸿电子科技(重庆)有限公司', '客户', '台湾双鸿科技股份有限公司'),
#  ('投资建议', '涉及', '三夫户外'),
#  ('公司研究/房地产/房地产', '涉及', '社区电商'),
#  ('迈过泥泞，方成涅槃——短期影响不改行业', '涉及', 'SARS'),
#  ('投资建议', '涉及', '天津市建委'),
#  ('周行情回顾', '涉及', '晶盛机电'),
#  ('评级：增持', '涉及', '及瑞吉酒店'),
#  ('证券研究报告/行业深度报告', '涉及', '新能源汽车行业'),
#  ('新冠疫情医药行业专题报告', '涉及', '凯普生物'),
#  ('国内', '发布', '计划'),
#  ('投资建议：疫情影响消退，把握券商银行', '涉及', '城商行'),
#  ('软磁：无线充电开启黄金时代', '涉及', '力量'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '涉及', '锦江区妇幼保健院'),
#  ('中国', '发布', '建议'),
#  ('疫情冲击旅游业既定预期，短期业绩承压，静候细分龙头复苏', '涉及', 'PE(TTM)'),
#  ('行业评级', '涉及', '小红书'),
#  ('新冠', '发布', '建议'),
#  ('危废垃圾双轮驱动，政策利好助力成长', '涉及', '平台'),
#  ('中国物业服务', '客户', '雅生活'),
#  ('国产化', '涉及', '上海化工区'),
#  ('新的起点，从5G看云', '涉及', '申万）'),
#  ('消失的需求，创造的消费，递延的社交——从需求类别看疫情对食品饮料行业的影响', '涉及', '2010年'),
#  ('和硕', '客户', '深圳市飞荣达科技股份有限公司'),
#  ('健康', '发布', '计划'),
#  ('投资建议', '涉及', '安道'),
#  ('aaS', '拥有', '微信商业生态发展不及预期'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '松下幸之助'),
#  ('隐形冠军的缔造与壁垒', '涉及', '2018'),
#  ('社区增值服务', '发布', '计划'),
#  ('HRCManagement', '发布', '规则'),
#  ('周行情回顾', '涉及', '科达利'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '瑞典OPCON'),
#  ('朗讯', '客户', '深圳市飞荣达科技股份有限公司'),
#  ('国内', '发布', '方案'),
#  ('投资建议', '涉及', '广汽本田'),
#  ('寿险销售的逆周期性与投资的稳定性', '涉及', '合众'),
#  ('持续改善中的电动车龙头', '涉及', '国产'),
#  ('复苏之路', '涉及', '霍尼韦尔'),
#  ('助生', '发布', '人类辅助生殖技术管理办法'),
#  ('基金', '发布', '计划'),
#  ('重点子行业疫情影响分析', '涉及', '农化'),
#  ('新的起点，从5G看云', '涉及', '迪普科技'),
#  ('报告摘要：', '涉及', '国网四川省电力公司'),
#  ('恒汇电缆', '发布', '议案'),
#  ('从FILA到Amer，新起点与新征程', '涉及', '迪桑特为'),
#  ('借助海上作业优势，布局海上风电项目', '涉及', '海上风电'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '松下'),
#  ('太二', '发布', '计划'),
#  ('物业服务', '客户', '雅生活'),
#  ('2018', '拥有', '佳贝艾特自'),
#  ('深度产业运营+投资，健康、快乐、富足生态步入收获期', '涉及', 'GlandPharma'),
#  ('卫计委', '发布', '规划指导原则'),
#  ('从两化协同看我国农业自主', '涉及', '荃银高科'),
#  ('周行情回顾', '涉及', '上证综'),
#  ('借助海上作业优势，布局海上风电项目', '涉及', '能源开发'),
#  ('有危才有机，疫情扰动不影响中长期成长逻辑', '涉及', '东南亚'),
#  ('手机产业系列报告之二', '涉及', '伟创力'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '涉及', '锦欣医疗投资管理集团'),
#  ('国家', '发布', '发出通知'),
#  ('估值与投资建议', '涉及', '金融资产'),
#  ('新冠疫情医药行业专题报告', '涉及', '以岭药业'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '融捷股份'),
#  ('助生', '发布', '协议'),
#  ('寿险销售的逆周期性与投资的稳定性', '涉及', '中国金茂'),
#  ('国产化', '涉及', '统计局'),
#  ('投资建议', '涉及', '2019Q1'),
#  ('上海工厂', '发布', '计划'),
#  ('证券研究报告', '涉及', '京东'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '宁德时代'),
#  ('聚焦中小客户分散风险', '涉及', '科技'),
#  ('银保监会', '发布', '关于推动银行业'),
#  ('国际油公司', '发布', '关于'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '涉及', '生殖中心'),
#  ('国产化', '涉及', '2019Q3公司'),
#  ('中国', '发布', '车联网（智能网联汽车）产业发展行动计划'),
#  ('中国证券监督管理委员会', '发布', '公告'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '保利发展控股集团'),
#  ('优异的辅助驾驶能力', '涉及', '工厂'),
#  ('各地政策放松及货币财政发力点评', '涉及', '保利'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '福建省市场监管局'),
#  ('追赶者在成熟制程还有机会', '涉及', '华虹'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '保利会展'),
#  ('证券研究报告', '涉及', 'Pass'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '加拿大巴拉德'),
#  ('HRC', '发布', '协议'),
#  ('深圳证券交易所', '发布', '规定'),
#  ('重构新消费：社交资产如何链接“品”与“效”', '涉及', '天猫淘宝'),
#  ('CNAS', '发布', '电动汽车用锂离子动力蓄电池安全要求'),
#  ('国产化', '涉及', '芯片企业'),
#  ('新的起点，从5G看云', '涉及', '亚马逊'),
#  ('年增速', '客户', '万宝盛华'),
#  ('卓越的能耗', '涉及', '斯拉'),
#  ('持续改善中的电动车龙头', '涉及', '浪潮'),
#  ('华源', '发布', '关于'),
#  ('天津鑫达瑞明企业管理咨询中心', '发布', '关于'),
#  ('新冠疫情医药行业专题报告', '涉及', '仙琚制药'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '中广核'),
#  ('中国', '发布', '人口与劳动绿皮书'),
#  ('投资建议', '涉及', '雷曼光电'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '涉及', '经原卫生部'),
#  ('证券研究报告|电气设备', '涉及', '中国'),
#  ('各地政策放松及货币财政发力点评', '涉及', '旭辉集团'),
#  ('行业评级强于大市(维持评级', '涉及', '“种草”'),
#  ('行业报告|行业研究周报', '涉及', '新能源汽车'),
#  ('国知发', '发布', '驰名商标认定和保护规定'),
#  ('半导体业务孕育巨大机会，业务', '涉及', '宁德时代'),
#  ('龙城物业管理', '开展', '建筑物'),
#  ('风险因素', '涉及', '国家'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '华源'),
#  ('从翻座率看，整体翻座率', '涉及', '中式'),
#  ('从SARS疫情复盘看新型冠状病毒肺炎对机械行业的影响', '涉及', '中国'),
#  ('资产管理', '发布', '资产收购协议'),
#  ('评级：买入上次评级：买入', '涉及', '广汽本田单'),
#  ('证券研究报告', '涉及', '欧普照明'),
#  ('MAP', '发布', '计划'),
#  ('行业投资风险', '涉及', 'CEO'),
#  ('行业观点', '涉及', '集团'),
#  ('鉴彼时以观今日，化工行业疫情影响解析', '涉及', '扬农'),
#  ('新冠疫情医药行业专题报告', '涉及', '国际'),
#  ('疫情影响分析：主要区域和产业链、供应链冲', '涉及', '东风'),
#  ('优异的辅助驾驶能力', '涉及', 'Mode'),
#  ('证券研究报告', '涉及', '海尔智家'),
#  ('新的起点，从5G看云', '涉及', '2011年'),
#  ('进击的酸菜鱼龙头', '涉及', '天津'),
#  ('行业报告|行业研究周报', '涉及', '上证'),
#  ('新的起点，从5G看云', '涉及', '交通管理'),
#  ('深度跟踪报告', '涉及', '2019Q2'),
#  ('轻资产', '涉及', '首旅'),
#  ('宁德', '发布', '公告'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '碧桂园'),
#  ('iPh', '发布', '协议'),
#  ('物业服务', '客户', '物业'),
#  ('新能源汽车', '拥有', '新能源汽车推广不及预期'),
#  ('增速，是最大风险点', '涉及', 'CATechnologies'),
#  ('行业评级强于大市(维持评级', '涉及', '商家'),
#  ('USB-IF', '发布', '协议'),
#  ('事件概述', '涉及', '广汽自主'),
#  ('基础设施', '发布', '规范'),
#  ('投资建议', '涉及', '助生'),
#  ('看好/维持', '涉及', '大族激光'),
#  ('软磁：无线充电开启黄金时代', '采用', '利润总额'),
#  ('远程办公产品之多媒体融合全面体验', '涉及', 'aaS'),
#  ('国网公司', '发布', '“三型两网”助力“两个高水平”建设战略合作框架协议'),
#  ('2019年业绩前瞻：稳健增长的一年', '涉及', '中国家用电器协会'),
#  ('上海明华物业管理', '开展', '建筑物'),
#  ('国产化', '涉及', 'ell'),
#  ('行业评级强于大市(维持评级', '涉及', '万能'),
#  ('评级：买入上次评级：买入', '涉及', '丰田'),
#  ('新的起点，从5G看云', '涉及', '网络设备'),
#  ('软磁：无线充电开启黄金时代', '涉及', '苹果'),
#  ('统计局', '发布', '年鉴'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '涉及', '保监会'),
#  ('疫情冲击旅游业既定预期，短期业绩承压，静候细分龙头复苏', '涉及', '北京'),
#  ('游戏强劲，在线教育', '涉及', '红黄蓝'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '能源电力集团'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '中国'),
#  ('投资建议', '涉及', '益丰药房'),
#  ('能源汽车', '拥有', '补贴大幅退坡'),
#  ('证券研究报告', '涉及', 'Altur'),
#  ('微笑曲线', '发布', '方案'),
#  ('内外两维度看美股风险收益比', '涉及', '美股'),
#  ('手机产业系列报告之二', '涉及', 'USB-IF'),
#  ('公建物业', '开展', '物业公司'),
#  ('工商', '发布', '公告'),
#  ('先导智能', '发布', '公告'),
#  ('鉴彼时以观今日，化工行业疫情影响解析', '涉及', '长江存储'),
#  ('大消费联合系列报告：不可忽视的刚需消费', '涉及', '屠宰业务公司'),
#  ('国产化', '涉及', '福特'),
#  ('投资建议', '涉及', '广汽本'),
#  ('证券研究报告/行业深度报告', '涉及', '基站'),
#  ('证券研究报告', '涉及', '中南建设'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', 'Tier1'),
#  ('历次疫情的启示', '涉及', '乌干达'),
#  ('游戏强劲，在线教育', '涉及', 'Edmodo'),
#  ('强强联合，共拓带电操作机器人百亿蓝海市场', '涉及', '通用设备'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '江苏'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '基础物管市场'),
#  ('科技', '发布', '高速光谱仪的研制'),
#  ('各地政策放松及货币财政发力点评', '涉及', '中国金茂'),
#  ('投资建议', '涉及', '阿比多尔'),
#  ('国产化', '涉及', '瑞典OPCON'),
#  ('科力远', '发布', '公告'),
#  ('证券研究报告|行业投资策略报告', '采用', '股息率'),
#  ('江苏安靠智能输电工程科技股份有限公司', '发布', '关于'),
#  ('投资建议', '涉及', '健康管理'),
#  ('疫情冲击旅游业既定预期，短期业绩承压，静候细分龙头复苏', '涉及', '海南'),
#  ('看好/维持', '涉及', 'PERC'),
#  ('王国纪', '发布', '王国纪元'),
#  ('教育部学校规建中心', '开展', '教育部'),
#  ('国产化', '涉及', 'AtlasCopco'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', 'CR5'),
#  ('事件概述', '涉及', '广本'),
#  ('埃尔福特', '发布', '关于'),
#  ('各地政策放松及货币财政发力点评', '涉及', '华夏幸福'),
#  ('证券研究报告', '涉及', 'Whabouchi锂矿'),
#  ('粮价波动与猪周期', '涉及', '国际'),
#  ('疫情影响分析：主要区域和产业链、供应链冲', '涉及', '中国'),
#  ('疫情影响分析：主要区域和产业链、供应链冲', '涉及', '新冠'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '贵州省能源局'),
#  ('轻资产', '涉及', '信息化'),
#  ('味好美公司', '发布', '方案'),
#  ('生命方舟生殖专科', '发布', '协议'),
#  ('云峰化工', '发布', '关于'),
#  ('追赶者在成熟制程还有机会', '涉及', '集成'),
#  ('新能源汽车', '发布', '能源技术革命创新行动计划（2016-2030年）'),
#  ('疫情影响分析：主要区域和产业链、供应链冲', '涉及', '东风汽车'),
#  ('哪些粮食作物价格可能', '涉及', '2010年'),
#  ('受中美大', '开展', '环境影响'),
#  ('物业', '开展', '装修'),
#  ('疫情凸显供应链地位', '涉及', '中商产业研究院'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '天创物业'),
#  ('汇川技术', '发布', '计划'),
#  ('行业评级强于大市(维持评级', '涉及', '网红'),
#  ('行业评级强于大市(维持评级', '涉及', '保险产品'),
#  ('住房和城乡建设部', '发布', '设计规范（征求意见稿）'),
#  ('公司研究/房地产/房地产', '涉及', '中国'),
#  ('公司深度研究|医疗保健', '涉及', '网络'),
#  ('中海油', '发布', '行动计划'),
#  ('HJT', '发布', '方案'),
#  ('持续改善中的电动车龙头', '涉及', '上海工厂'),
#  ('通信网关', '发布', '公告'),
#  ('进击的酸菜鱼龙头', '涉及', '那未大叔是大厨'),
#  ('游戏强劲，在线教育迎风起航', '涉及', '教育部学校规建中心'),
#  ('从SARS疫情复盘看新型冠状病毒肺炎对机械行业的影响', '涉及', '中央应对疫情工作领导小组'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', 'Model3'),
#  ('投资建议', '涉及', 'ATL'),
#  ('寿险销售的逆周期性与投资的稳定性', '涉及', '银保监会'),
#  ('投资建议', '涉及', '台积电'),
#  ('潮平两岸阔，风正一帆悬', '涉及', '合肥万科'),
#  ('国产化', '涉及', '柏林工厂'),
#  ('能源', '发布', '“十三五”国家战略性新兴产业发展规划'),
#  ('国产化', '采用', '年复合增速'),
#  ('证券研究报告|行业投资策略', '采用', '股息率'),
#  ('迈过泥泞，方成涅槃——短期影响不改行业趋势，龙头公司韧性逐渐体现', '涉及', '东南'),
#  ('新能源汽车产业发展规划', '发布', '规划'),
#  ('从FILA到Amer，新起点与新征程', '涉及', '2019H1公司'),
#  ('他山之石，从龟甲万、味好美看调味品公司发展路径', '涉及', '茂木家族'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '党组'),
#  ('轻资产', '涉及', '鸿路钢构'),
#  ('南京星源”', '发布', '公告'),
#  ('新的起点，从5G看云', '涉及', 'EBITDA'),
#  ('公司深度研究|食品、饮料与烟草', '涉及', '精准'),
#  ('集团有限公司', '发布', '规划'),
#  ('物业管理公司', '发布', '计划'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '安控科技'),
#  ('卓越的能耗', '涉及', '吉利'),
#  ('投资建议', '涉及', '对扬农'),
#  ('西北菜&酸菜鱼龙头，规模化扩张与品质化提升并举', '涉及', '健康'),
#  ('行情回顾', '涉及', '华大基因'),
#  ('鉴彼时以观今日，化工行业疫情影响解析', '涉及', 'MDI'),
#  ('人才寻访：高毛利业务，量价双增促成长', '涉及', '人力咨询服务'),
#  ('从两化协同看我国农业', '涉及', '服务中心'),
#  ('行业评级强于大市(维持评级', '涉及', '政府'),
#  ('国改提速，预焕新生', '涉及', '以上汽'),
#  ('凯发电气', '发布', '国家企业技术中心认定管理办法'),
#  ('跟随大市(维持', '涉及', 'Model3'),
#  ('国知', '发布', '条例'),
#  ('新的起点，从5G看云', '涉及', 'AOI'),
#  ('行业评级强于大市(维持评级', '涉及', '三只'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '芯片设计'),
#  ('从FILA到Amer，新起点与新征程', '涉及', '所罗门'),
#  ('国产化', '涉及', '协会'),
#  ('国产化', '涉及', '电池工厂'),
#  ('投资建议', '涉及', '科达摩云致邻'),
#  ('迈为股份', '客户', 'Baccini'),
#  ('国产化', '涉及', '国资'),
#  ('国产化', '涉及', 'SFC'),
#  ('国产化', '涉及', 'SRM'),
#  ('轻资产', '涉及', '太二'),
#  ('重构新消费：社交资产如何链接“品”与“效”', '涉及', '淘内'),
#  ('行业评级强于大市(维持评级)上次评级强于大市', '涉及', '保单'),
#  ('国产化', '涉及', '隆基乐叶'),
#  ('国产化', '涉及', '美国能源部门'),
#  ('国知', '发布', '国家知识产权局关于“'),
#  ('集团', '发布', '公告'),
#  ('各类传感器有望', '涉及', '架构'),
#  ('深圳中山', '开展', '外科'),
#  ('国改提速，预焕新生', '涉及', '恒立液压'),
#  ('风险因素', '涉及', 'Nike'),
#  ('风险因素', '涉及', '国家统计局'),
#  ('证券研究报告', '涉及', '力量'),
#  ('电池', '发布', '节能与新能源汽车产业发展规划（2012-2020年）'),
#  ('北京', '发布', '规范'),
#  ('从SARS疫情复盘看新型冠状病毒肺炎对机械行业的影响', '涉及', '欧美'),
#  ('证券研究报告|行业周报', '涉及', '小熊'),
#  ('架构', '发布', '协议'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', 'ard'),
#  ('疫情冲击旅游业既定预期，短期业绩承压，静候细分龙头复苏', '采用', '沪深300'),
#  ('评级：增持', '涉及', '及塔牌集团'),
#  ('软磁：无线充电开启黄金时代', '涉及', '奔驰'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '事会'),
#  ('证券研究报告/行业深度报告', '涉及', 'PHEV'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '电车汇'),
#  ('供应链问题', '涉及', '科技'),
#  ('新能源汽车积分并行管理办法》的决定（征求意见稿', '发布', '乘用车企业平均燃料消耗量与新能源汽车积分并行管理办法》修正案（征求意见稿'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '中国工厂'),
#  ('服务器拐点即将来临', '涉及', '联通'),
#  ('行业观点', '涉及', 'USFoodsHolding'),
#  ('服务器拐点即将来临', '涉及', '边缘计算'),
#  ('宁波银行股份有限公司', '发布', '关于收到民事裁定书暨银行账户被冻结的公告'),
#  ('重点子行业疫情影响分析', '涉及', '万润股份'),
#  ('软磁：无线充电开启黄金时代', '涉及', '芯片'),
#  ('汽车与汽车零部件', '涉及', '海外'),
#  ('江苏省人大', '发布', '江苏省电力条例'),
#  ('强强联合，共拓带电操作机器人百亿蓝海市场', '涉及', '商飞'),
#  ('估值与投资建议', '涉及', '总部'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '飞驰汽车'),
#  ('历次疫情的启示', '涉及', '力拓公司'),
#  ('手机用户', '属于', 'AirPods'),
#  ('对扬农', '发布', '规划'),
#  ('投资建议', '涉及', '广汽自主'),
#  ('行业评级强于大市(维持评级', '涉及', '能源'),
#  ('“公司', '发布', '关于第三期股权激励计划所涉限制性股票第三个解锁期解锁条件成就的议案'),
#  ('粮食会是明年', '涉及', '国外'),
#  ('上海新时达电气股份有限公司', '发布', '规定'),
#  ('——', '发布', '规范'),
#  ('证券研究报告', '涉及', '总部'),
#  ('国网浙江省电力有限公司', '发布', '协议'),
#  ('行业观点', '涉及', '新东方'),
#  ('疫情凸显供应链地位', '涉及', '中国烹饪协会'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '涉及', '生命方舟生殖专科联盟'),
#  ('行情回顾', '涉及', '万孚生物'),
#  ('历次疫情的启示', '涉及', '教育部'),
#  ('新的起点，从5G看云', '涉及', '基金'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '2019Q4'),
#  ('卫计委', '发布', '规划'),
#  ('行情回顾', '涉及', '平台'),
#  ('行业评级', '涉及', '对扬农'),
#  ('国家邮政局', '发布', '计划'),
#  ('持续改善中的电动车龙头', '涉及', '特斯拉上海工厂'),
#  ('佛山市顺德区市场监督管理局', '发布', '关于'),
#  ('优异的辅助驾驶能力', '涉及', '凯美瑞'),
#  ('行情回顾', '涉及', '2018'),
#  ('国产化', '涉及', 'Ballard'),
#  ('投资建议', '涉及', '克而瑞'),
#  ('英威腾电气股份有限公司', '发布', '公告'),
#  ('马斯克', '发布', '特斯拉秘密宏图'),
#  ('特斯拉专题系列报告（一）：', '涉及', '新能源公交'),
#  ('消失的需求，创造的消费，递延的社交——从需求类别看疫情对食品饮料行业的影响', '涉及', '奈雪'),
#  ('新冠疫情医药行业专题报告', '涉及', 'SARS'),
#  ('投资建议', '涉及', 'PC龙头'),
#  ('大消费联合系列报告：不可忽视的刚需消费', '涉及', '协同'),
#  ('粮食价格波动与猪周期之间关系如何', '涉及', '国三'),
#  ('能源', '拥有', '新能源汽车推广不及预期'),
#  ('交通管理', '发布', 'C-V2X产业化路径和时间表研究白皮书'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '国际学校'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '中国质量认证中心'),
#  ('新雷能科技股份有限公司', '发布', '关于'),
#  ('投资建议', '涉及', 'Capex'),
#  ('强强联合，共拓带电操作机器人百亿蓝海市场', '涉及', '工厂'),
#  ('羊奶粉龙头，业绩增长', '涉及', '飞鹤全球'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '三星德克萨斯州工厂'),
#  ('证券研究报告', '涉及', '国债'),
#  ('金界', '拥有', '金界三期进度慢于预期风险'),
#  ('百年疫情史：病毒改变了啥', '涉及', '上证'),
#  ('重构新消费：社交资产如何链接“品”与“效”', '涉及', '移动'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '璞泰来'),
#  ('国网', '发布', '通知书'),
#  ('羊奶粉龙头，业绩增长', '涉及', '精准'),
#  ('新加坡', '发布', '公告'),
#  ('助生', '发布', '人类辅助生殖技术配置规划指导原则（2015版）'),
#  ('粮食价格波动与猪周期之间关系如何', '涉及', '汇易'),
#  ('新冠疫情医药行业专题报告', '涉及', '艾棣维欣'),
#  ('物业服务', '发布', '公告'),
#  ('兆新实业有限公司', '发布', '公司注册证明书'),
#  ('行业评级强于大市(维持评级', '涉及', '特锐德'),
#  ('商誉减值风险', '涉及', '海外'),
#  ('投资建议', '涉及', '万达信息'),
#  ('证券研究报告', '涉及', '万宝瑞华'),
#  ('公告点评|耐用消费品与服装', '涉及', 'Amer'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '新能源车企'),
#  ('国家发展改革委', '发布', '发出通知'),
#  ('长期的成长性', '涉及', '国家'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '宁德'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '国网浙江省电力有限公司'),
#  ('东方日升', '发布', '计划'),
#  ('国产化', '涉及', '印度'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '新能源汽车行业'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', 'IPO'),
#  ('合肥太阳能', '发布', '议案'),
#  ('他山之石，从龟甲万、味好美看调味品公司发展路径', '涉及', '电商'),
#  ('投资建议', '采用', '的股息率'),
#  ('从翻座率看，整体翻座率', '涉及', '国内'),
#  ('投资建议', '涉及', 'Max'),
#  ('电池', '发布', '协议书'),
#  ('CNAS', '发布', '电力储能用锂离子电池'),
#  ('各类传感器有望', '涉及', 'Model'),
#  ('北师大', '开展', '建设项目'),
#  ('江苏林洋能源股份有限公司', '发布', '关于'),
#  ('金域医学湖北子公司', '发布', '通知'),
#  ('证券研究报告|行业投资策略报告', '涉及', '保利'),
#  ('国产化', '涉及', '能源署'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '新时达电气股份有限公司'),
#  ('江苏', '发布', '江苏省电力条例'),
#  ('他山之石，从龟甲万、味好美看调味品公司发展路径', '涉及', '世纪经济'),
#  ('无锡市恒汇电缆有限公司', '发布', '关于'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '智电汽车'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '董事会'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '宏发股份'),
#  ('金川电子', '发布', '计划'),
#  ('手机产业系列报告之二', '涉及', '鸿富锦'),
#  ('证券研究报告', '涉及', '正极'),
#  ('危废垃圾双轮驱动，政策利好助力成长', '涉及', '广发建材行业研究小组'),
#  ('投资建议', '涉及', '云致邻'),
#  ('移动', '发布', '公告'),
#  ('投资建议', '涉及', '苏州金龙'),
#  ('特斯拉专题系列报告（一）：', '涉及', '2018'),
#  ('国产化', '涉及', '中通客车'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '意法半导体'),
#  ('国产化', '涉及', '巴拉德'),
#  ('公司研究/房地产/房地产', '涉及', '雅居乐物业'),
#  ('历次疫情的启示', '涉及', '非洲经济简报'),
#  ('合肥广合', '发布', '协议'),
#  ('新的起点，从5G看云', '涉及', '信通院'),
#  ('东方日升', '发布', '议案'),
#  ('HJT', '发布', '公告'),
#  ('国产化', '涉及', '深圳市雄韬股份'),
#  ('合肥广合产业投资中心', '发布', '资产收购协议'),
#  ('锂电铜箔：深蹲', '涉及', '中科三环'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', 'LGChem'),
#  ('投资建议', '涉及', '日本国土交通省'),
#  ('雅生活股份', '客户', '雅生活'),
#  ('疫情冲击旅游业既定预期，短期业绩承压，静候细分龙头复苏', '涉及', '旅行社'),
#  ('国产化', '涉及', '中国大陆设计公司'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', 'Manageme'),
#  ('能源技术', '发布', '计划'),
#  ('资产管理', '开展', '房屋'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '中鼎集成'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '涉及', '殖医学科'),
#  ('思科', '客户', '深圳市飞荣达科技股份有限公司'),
#  ('PERC', '发布', '规划'),
#  ('投资建议', '涉及', '质量检验部'),
#  ('物业', '发布', '协议'),
#  ('安靠智能输电工程科技股份有限公司', '发布', '关于'),
#  ('从FILA到Amer，新起点与新征程', '涉及', '2018'),
#  ('卓越的能耗', '涉及', '芯片'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '湖南保利天创'),
#  ('锂供需边际改善也是题中之义，行业持续', '涉及', '2019Q1'),
#  ('优异的辅助驾驶能力', '涉及', '新一代'),
#  ('物流运输略有好转，农资产品价格上行', '涉及', '中化'),
#  ('Wi-Fi6：拐点已至', '涉及', 'Celeno'),
#  ('估值与投资评级', '涉及', '中汽协'),
#  ('消失的需求，创造的消费，递延的社交——从需求类别看疫情对食品饮料行业的影响', '涉及', '中、'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '天津巴莫'),
#  ('行情回顾', '涉及', '如洛匹那韦等'),
#  ('轻资产', '涉及', '政府'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '关联公司'),
#  ('公司研究/房地产/房地产', '涉及', '世界'),
#  ('投资建议', '涉及', '保监会'),
#  ('软磁：无线充电开启黄金时代', '涉及', '新能源总经理'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '南都电源'),
#  ('证券研究报告·行业研究·文化传媒', '涉及', '联盟游戏公司'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '国家'),
#  ('增速，是最大风险点', '涉及', '国外'),
#  ('投资建议', '涉及', '梦网视信'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '上海纽安洁'),
#  ('PERI', '发布', '公告'),
#  ('广发证券', '发布', '关于'),
#  ('手机产业系列报告之二', '涉及', '新美亚'),
#  ('证券研究报告•行业研究•汽车', '涉及', 'Mod'),
#  ('远程办公产品之多媒体融合全面体验', '涉及', '云致邻'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '能源技术'),
#  ('公司研究/房地产/房地产', '涉及', '400呼叫中心'),
#  ('浙江省市场监督管理局', '发布', '关于'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '国网山东省电力公司'),
#  ('证券研究报告', '涉及', 'Galaxy'),
#  ('轻资产', '涉及', '千味央'),
#  ('公司深度研究|食品、饮料与烟草', '涉及', 'AunulifePtyLtd'),
#  ('持续改善中的电动车龙头', '涉及', '保时捷'),
#  ('快驴事业部', '客户', '生鲜'),
#  ('他山之石，从龟甲万、味好美看调味品公司发展路径', '涉及', '味之素'),
#  ('国家电网有限公司', '发布', '公告'),
#  ('轻资产', '涉及', '力量'),
#  ('爱立信', '客户', '北京中石伟业科技股份有限公司'),
#  ('他山之石，从龟甲万、味好美看调味品公司发展路径', '涉及', '海天和味好美则'),
#  ('投资建议', '涉及', '中信'),
#  ('国产化', '涉及', 'ModelY'),
#  ('中国智慧交通管理产业联盟', '发布', 'C-V2X产业化路径和时间表研究白皮书'),
#  ('重点子行业疫情影响分析', '涉及', '道恩股份'),
#  ('从FILA到Amer，新起点与新征程', '涉及', '全球运动品牌集团'),
#  ('LG化学', '发布', '新能源汽车推广应用推荐车型目录'),
#  ('中国', '发布', '2019年度中国电动汽车充电设施技术发展白皮书之二：无线充电'),
#  ('SaaS', '拥有', '行业竞争致获客成本增长，亏损扩大'),
#  ('轻资产', '涉及', '能源'),
#  ('行业评级强于大市(维持评级', '涉及', '百度'),
#  ('轻资产', '涉及', '光大'),
#  ('锦江区妇幼保健院', '发布', '协议'),
#  ('携手“鲲鹏”，展翅入“云', '涉及', '基石'),
#  ('强强联合，共拓带电操作机器人百亿蓝海市场', '涉及', '国家电网'),
#  ('投资建议', '涉及', 'Virtuoso'),
#  ('中国', '发布', '节能与新能源汽车产业发展规划（2012-2020年）'),
#  ('行业研究/机械工业', '涉及', '工程机械协会'),
#  ('远程办公产品之多媒体融合全面体验', '涉及', '中软国际'),
#  ('哪些粮食作物价格可能', '涉及', '国外'),
#  ('新的起点，从5G看云', '涉及', '中国智能网联汽车产业创新联盟'),
#  ('国内', '发布', '乘用车企业平均燃料消耗量与新能源汽车积分并行管理办法》修正案（征求意见稿'),
#  ('轻资产', '涉及', '绿筑集成科技'),
#  ('社交属性消费递延', '涉及', '基地'),
#  ('国产化', '涉及', 'CATL'),
#  ('潮平两岸阔，风正一帆悬', '涉及', '新能源汽车'),
#  ('从FILA到Amer，新起点与新征程', '涉及', 'Descente'),
#  ('半导体业务孕育巨大机会，业务', '涉及', '电池工厂'),
#  ('Amer', '发布', '关于'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '2011年'),
#  ('国知发', '发布', '商标法'),
#  ('国家税务总局', '发布', '关于发布2019'),
#  ('受疫情影响相对较小，短期车险赔付率有望改善', '涉及', 'ROE'),
#  ('特斯拉专题系列报告（一）：', '涉及', '中国'),
#  ('高精度地图有望迎来成长拐点', '涉及', '智能网联汽车'),
#  ('他山之石，从龟甲万、味好美看调味品公司发展路径', '涉及', '茂木'),
#  ('国内', '属于', '电池'),
#  ('国产化', '涉及', '海思'),
#  ('云计算', '发布', '建议'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '电池事业本部'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '海为支油'),
#  ('结论和投资建议', '涉及', '国家'),
#  ('看好/维持', '涉及', '理想能源'),
#  ('物业服务', '发布', '中国特色物业服务领先企业—'),
#  ('追赶者在成熟制程还有机会', '涉及', '国内'),
#  ('证券研究报告|行业投资策略', '涉及', '中国工商银行绍兴分行'),
#  ('欧盟', '拥有', '“悠蓝'),
#  ('行业评级强于大市(维持评级', '涉及', '晶盛机电'),
#  ('各类传感器有望', '涉及', '小鹏'),
#  ('投资建议', '涉及', '科达摩云'),
#  ('国际', '开展', '教育领域'),
#  ('证券研究报告/行业深度报告证券研究报告/行业深度报告', '涉及', '能源'),
#  ('行业评级强于大市(维持评级)上次评级强于大市', '涉及', '国际'),
#  ('日本', '发布', '住宅金融公库法'),
#  ('投资建议', '涉及', '年雅居乐集团'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', 'Hydrogenics'),
#  ('深度产业运营+投资，健康、快乐、富足生态步入收获期', '涉及', '星益健康管理'),
#  ('深度产业运营+投资，健康、快乐、富足生态步入收获期', '涉及', 'dical'),
#  ('拳头游戏下行，静待新游接棒', '涉及', '莉莉丝游戏'),
#  ('携手“鲲鹏”，展翅入“云', '涉及', '鲲鹏生态建设'),
#  ('行业评级', '涉及', '国内'),
#  ('鉴彼时以观今日，化工行业疫情影响解析', '涉及', '天马'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '精锐股份'),
#  ('深度产业运营+投资，健康、快乐、富足生态步入收获期', '涉及', '协同'),
#  ('粮食会是明年通胀的风险因素吗', '涉及', '以麦叶蜂'),
#  ('羊奶粉龙头，业绩增长', '涉及', '新西兰'),
#  ('物业管理', '发布', '战略规划'),
#  ('行业评级', '涉及', '中介'),
#  ('国产化', '涉及', '中环半导体'),
#  ('特斯拉专题系列报告（一）：', '涉及', '上海市2018'),
#  ('新冠疫情医药行业专题报告', '涉及', '国家'),
#  ('政府', '发布', '建议'),
#  ('国产化', '涉及', '欧美'),
#  ('新的起点，从5G看云', '涉及', '浪潮信息'),
#  ('行业评级强于大市(维持评级', '涉及', '保单'),
#  ('行业评级', '涉及', 'MAP'),
#  ('行业评级强于大市(维持评级)上次评级强于大市', '涉及', '健康管理'),
#  ('国产化', '涉及', '恒玄'),
#  ('中国', '发布', '2019中国物业服务百强企业研究报告'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '新能源汽车推广应用推荐车型目录'),
#  ('投资建议', '涉及', '天孚通信'),
#  ('佛山市顺德区市场监督管理局', '发布', '公告'),
#  ('国产化', '涉及', 'IEA'),
#  ('证券研究报告·行业研究·文化传媒', '涉及', '网络'),
#  ('证券研究报告/行业深度报告', '涉及', '澳大利亚矿业公司'),
#  ('生命方舟', '发布', '协议'),
#  ('卫健委妇幼健康', '发布', 'ReproductiveBiologyandEndocrinology'),
#  ('东方', '发布', '公告'),
#  ('天津', '发布', '办法'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '捷威动力工业有限公司'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '能源'),
#  ('估值与投资建议', '涉及', '西囡'),
#  ('从SARS疫情复盘看新型冠状病毒肺炎对机械行业的影响', '涉及', '世界'),
#  ('新能源', '发布', '新能源汽车产业发展规划（2021-2025）'),
#  ('追赶者在成熟制程还有机会', '涉及', '海外'),
#  ('北京新雷能科技股份有限公司公司子', '发布', '关于'),
#  ('寿险销售的逆周期性与投资的稳定性', '涉及', '中国人寿'),
#  ('鉴彼时以观今日，化工行业疫情影响解析', '涉及', '中国饲料行业'),
#  ('保利发展', '客户', '保利物业'),
#  ('游戏强劲，在线教育迎风起航', '涉及', 'K-12国际学校'),
#  ('投资建议', '涉及', '2018'),
#  ('4季度中场业务仍然有所增长', '涉及', '西翼赌厅'),
#  ('吉利德瑞德西韦', '发布', '计划'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '涉及', '2010年'),
#  ('半导体业务孕育巨大机会，业务', '涉及', '捷佳伟创'),
#  ('优异的辅助驾驶能力', '涉及', '电池'),
#  ('半导体业务孕育巨大机会，业务', '涉及', '山煤国际'),
#  ('长期的成长性', '涉及', '双汇'),
#  ('轻资产', '涉及', '19H1公司'),
#  ('事会', '发布', '关于使用部分闲置募集资金临时补充流动资金的议案'),
#  ('Yamasa', '拥有', '市场竞争加剧'),
#  ('鉴彼时以观今日，化工行业疫情影响解析', '涉及', '安迪苏'),
#  ('天源迪科', '发布', '公告'),
#  ('跟随大市(维持', '涉及', '国产'),
#  ('国家', '发布', '道路机动车辆生产企业及产品公告'),
#  ('上海证券交易所', '发布', '计划'),
#  ('中国智能网联汽车产业创新联盟', '发布', '白皮书'),
#  ('借助海上作业优势，布局海上风电项目', '涉及', '国内'),
#  ('VIP', '客户', '九毛'),
#  ('总部', '开展', '传染'),
#  ('新的起点，从5G看云', '涉及', '国产'),
#  ('国产化', '涉及', '杰理'),
#  ('危废垃圾双轮驱动，政策利好助力成长', '涉及', '广发证券发展研究中心'),
#  ('软磁：无线充电开启黄金时代', '涉及', 'Galaxy'),
#  ('科技', '发布', '关于'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '比亚迪e'),
#  ('北京', '发布', '公告'),
#  ('ModelY', '拥有', '特斯拉中国Model3订单不及预期'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', 'CAGR'),
#  ('社融超预期，把握行情机会', '涉及', '城商行'),
#  ('新能源公交', '发布', '关于进一步完善新能源汽车推广应用财政补贴政策的通知'),
#  ('锦欣成都网络内辅助生殖医疗机构', '发布', '协议'),
#  ('设施设备养护及维修、客户服务、前期咨询服务', '客户', '物业'),
#  ('金融中心', '发布', '关于进一步加快上海国际金融中心建设和金融支持长三角一体化发展的意见'),
#  ('诺德投资股份有限公司', '发布', '公告'),
#  ('强强联合，共拓带电操作机器人百亿蓝海市场', '涉及', '电池'),
#  ('那未', '客户', '九毛'),
#  ('2018', '开展', '生态建设'),
#  ('证券研究报告·行业研究·文化传媒', '涉及', '安卓'),
#  ('国产化', '涉及', '大众'),
#  ('市场监督管理局', '发布', '关于'),
#  ('特斯拉专题系列报告（一）：', '涉及', '北京'),
#  ('电池', '发布', '关于建设欧洲生产研发基地的议案'),
#  ('科力远集团', '发布', '计划'),
#  ('卓越的能耗', '涉及', '美股'),
#  ('国产化', '涉及', '凯美瑞LE'),
#  ('2018', '发布', '关于'),
#  ('西北菜&酸菜鱼龙头，规模化扩张与品质化提升并举', '涉及', '总部'),
#  ('投资建议', '涉及', '基础设施'),
#  ('半导体行情的风险是什么', '涉及', '恒玄'),
#  ('投资建议', '涉及', '服务平台'),
#  ('半导体业务孕育巨大机会，业务', '涉及', '上机今年'),
#  ('华西能源', '发布', '关于'),
#  ('新的起点，从5G看云', '涉及', 'ment'),
#  ('东南亚', '拥有', '新冠疫情加剧风险'),
#  ('大众', '发布', '方案'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '涉及', 'Fertility'),
#  ('投资建议', '涉及', 'VIP'),
#  ('中国幼', '开展', '教育'),
#  ('历次疫情的启示', '采用', '年增速'),
#  ('天津市电力公司', '发布', '公告'),
#  ('江苏', '发布', '规范'),
#  ('锂业公司', '发布', '计划'),
#  ('行业评级', '涉及', 'ODM工厂'),
#  ('生殖中心', '发布', '规划'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '深圳'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '中国指数研究院'),
#  ('西囡医院', '客户', '国际'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '日本丸红'),
#  ('康定市人民政府', '发布', '战略规划'),
#  ('供应链问题', '涉及', '微商城'),
#  ('他山之石，从龟甲万、味好美看调味品公司发展路径', '涉及', '太平贸易株式会社'),
#  ('国改提速，预焕新生', '涉及', 'EPS'),
#  ('2018', '发布', '企划'),
#  ('绿地', '客户', '雅生活'),
#  ('轻资产', '涉及', '腾讯'),
#  ('隐形冠军的缔造与壁垒', '涉及', '天猫市'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '“云峰化工'),
#  ('中电联', '发布', '白皮书'),
#  ('西北菜&酸菜鱼龙头，规模化扩张与品质化提升并举', '涉及', '杜邦'),
#  ('各类传感器有望', '涉及', 'Infineon'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '国Dana'),
#  ('估值与投资评级', '涉及', '长城'),
#  ('他山之石，从龟甲万、味好美看调味品公司发展路径', '涉及', '中国'),
#  ('公司研究/房地产/房地产', '涉及', '便利店'),
#  ('丰田', '发布', '深化战略合作框架协议'),
#  ('联盟', '发布', '跳舞的线'),
#  ('估值与投资建议', '涉及', '深圳'),
#  ('行业评级强于大市(维持评级', '涉及', '基金'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '国家'),
#  ('证券研究报告', '涉及', '睿仕'),
#  ('软磁：无线充电开启黄金时代', '涉及', '中兴'),
#  ('游戏强劲，在线教育', '涉及', '贝斯特'),
#  ('投资建议', '涉及', '华联'),
#  ('迈过泥泞，方成涅槃——短期影响不改行业趋势，龙头公司韧性逐渐体现', '涉及', '巴奴毛肚'),
#  ('创新人力资源领导者，灵活用工驱动高成长', '涉及', '零售'),
#  ('“云峰化工', '发布', '公告'),
#  ('电池', '发布', '电力储能用锂离子电池'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '德方纳米'),
#  ('证券研究报告', '涉及', '中东'),
#  ('国产化', '涉及', '上海电驱动'),
#  ('百年疫情史：病毒改变了啥', '涉及', '基建'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', 'LG化学'),
#  ('平台', '开展', '教育'),
#  ('跟随大市', '涉及', '基地'),
#  ('从FILA到Amer，新起点与新征程', '涉及', 'AmerSports'),
#  ('江苏阳恒化工有限公司', '发布', '关于江苏阳恒吸收合并江苏震宇的框架协议'),
#  ('国产化', '涉及', '汇顶科技'),
#  ('深度产业运营+投资，健康、快乐、富足生态步入收获期', '涉及', '富足生态'),
#  ('长期的成长性', '涉及', '网络'),
#  ('投资建议', '涉及', '阿特斯'),
#  ('借助海上作业优势，布局海上风电项目', '涉及', '中、'),
#  ('行业评级强于大市(维持评级', '涉及', '欧莱雅'),
#  ('网络', '拥有', '家九毛九'),
#  ('手机产业系列报告之二', '涉及', '通信'),
#  ('证券研究报告', '涉及', 'EventElite'),
#  ('证券研究报告|行业投资策略报告', '涉及', '融创中国'),
#  ('国产化', '涉及', '世界'),
#  ('新能源', '发布', '办法'),
#  ('中国', '发布', '中华人民共和国政府和美利坚合众国政府经济贸易协议'),
#  ('广汽', '发布', '协议'),
#  ('东南亚', '拥有', '市场竞争加剧'),
#  ('投资建议', '涉及', '国资'),
#  ('公司深度研究|食品、饮料与烟草', '涉及', '澳优'),
#  ('卫健委妇幼健康', '发布', '公报'),
#  ('BradfordA.Kolb', '发布', '规则'),
#  ('PHEV', '发布', '战略规划'),
#  ('轻资产', '涉及', '健康咨询服务'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '深圳'),
#  ('投资建议', '涉及', '海南区域'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '住友化学'),
#  ('大消费联合系列报告：不可忽视的刚需消费', '涉及', '新希望'),
#  ('国产化', '涉及', '集成'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '融捷股份有限公司'),
#  ('投资建议', '涉及', '腾讯会议'),
#  ('中新赛克', '发布', '建议'),
#  ('投资建议', '涉及', '苏州金龙及'),
#  ('2018', '发布', '部分产能过剩行业产能置换实施办法'),
#  ('2018', '拥有', '供应链风险'),
#  ('投资建议', '涉及', '1H2019公司'),
#  ('行业观点', '涉及', '首旅'),
#  ('aaS', '开展', '建设项目'),
#  ('龟甲', '拥有', '市场竞争加剧'),
#  ('他山之石，从龟甲万、味好美看调味品公司发展路径', '涉及', '味好美营收'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '现代'),
#  ('行业评级强于大市(维持评级', '涉及', '抖音'),
#  ('Gigafactory1', '发布', '计划'),
#  ('行情回顾', '涉及', 'CQC'),
#  ('ent', '开展', '信息技术及网络服务'),
#  ('报告摘要：', '涉及', '深圳市禾望电气股份有限公司'),
#  ('汽车与汽车零部件', '涉及', '能源'),
#  ('行业报告|行业研究周报', '涉及', 'Mod'),
#  ('新冠疫情医药行业专题报告', '涉及', '申万'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '上海明华物业'),
#  ('国产化', '涉及', '英特尔'),
#  ('工程机械', '拥有', '机械行业行业竞争加剧'),
#  ('MineralResources', '发布', '计划'),
#  ('投资建议', '涉及', '优嘉'),
#  ('大消费联合系列报告：不可忽视的刚需消费', '涉及', '华联综超超市'),
#  ('行情回顾', '涉及', '中信'),
#  ('轻资产', '涉及', '之云Z-Cloud'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '中民物业'),
#  ('国内', '开展', '教育'),
#  ('投资建议', '涉及', '集成电路基金'),
#  ('百年疫情史：病毒改变了啥', '涉及', '韩国现代经济研究院'),
#  ('国产化', '涉及', '以捷佳伟创为'),
#  ('受益于微信商业生态提速', '涉及', '联盟'),
#  ('电池', '发布', '汽车产业调整和振兴规划'),
#  ('深度跟踪报告', '涉及', '耐克'),
#  ('报告摘要：', '涉及', '福科产业运营管理有限公司'),
#  ('半导体行情的风险是什么', '涉及', '格罗方德'),
#  ('公司深度研究|食品、饮料与烟草', '涉及', '国产'),
#  ('趋势：风往哪里吹', '涉及', '淘宝'),
#  ('国改提速，预焕新生', '涉及', '工程机械'),
#  ('迈过泥泞，方成涅槃——短期影响不改行业趋势，龙头公司韧性逐渐体现', '涉及', '旅客量'),
#  ('2019年业绩前瞻：稳健增长的一年', '涉及', '协同'),
#  ('投资建议', '涉及', '贵宾'),
#  ('实验室', '发布', '新型冠状病毒感染的肺炎实验室检测技术指南（第三版）'),
#  ('世界', '发布', 'ReproductiveBiologyandEndocrinology'),
#  ('投资建议', '涉及', '复星联合健康险'),
#  ('从翻座率看，整体翻座率', '采用', '总资产周转率'),
#  ('投资建议', '涉及', '捷佳伟创'),
#  ('卓越的能耗', '涉及', '2019Q4'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '印度Pinnacle'),
#  ('新能源汽车产业', '发布', '计划'),
#  ('行业评级强于大市(维持评级', '涉及', '零售'),
#  ('IPO', '发布', '计划'),
#  ('卓越的能耗', '涉及', '新造车'),
#  ('国产化', '涉及', '埃隆马斯克'),
#  ('手机产业系列报告之二', '涉及', '捷普'),
#  ('国债', '发布', '规定'),
#  ('本轮半导体行情的四个逻辑', '涉及', '中兴'),
#  ('新的起点，从5G看云', '涉及', '复盘通信'),
#  ('新能源股份有限公司', '发布', '关于使用部分闲置募集资金暂时补充流动资金的议案'),
#  ('优异的辅助驾驶能力', '涉及', '新能源汽车'),
#  ('寿险销售的逆周期性与投资的稳定性', '涉及', '银保监会资金部'),
#  ('复星', '发布', '财富'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '中国汽车动力电池产业创新联盟'),
#  ('受益于微信商业生态提速', '涉及', '梦洁家纺'),
#  ('卓越的能耗', '涉及', '电池'),
#  ('投资建议', '涉及', '金科股份'),
#  ('“公司', '发布', '关于用闲置募集资金暂时补充流动资金的议案'),
#  ('投资建议', '涉及', '烽火通信'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '涉及', '生命方舟生殖专科'),
#  ('重构新消费：社交资产如何链接“品”与“效”', '涉及', 'SMART'),
#  ('羊奶粉龙头，业绩增长', '涉及', 'Neolac悠蓝'),
#  ('行业评级', '涉及', '特斯拉始入华，探析市场竞争力'),
#  ('证券研究报告/行业深度报告', '涉及', '新能源车'),
#  ('国家', '发布', '商标法实施条例'),
#  ('华西能源工业股份有限公司', '发布', '规定'),
#  ('锦欣', '发布', '协议书'),
#  ('人才寻访：高毛利业务，量价双增促成长', '涉及', '2018'),
#  ('上海虹桥枢纽西交通中心', '开展', '交通'),
#  ('社交属性消费递延', '涉及', '社交'),
#  ('雅生活', '发布', '规范'),
#  ('从SARS疫情复盘看新型冠状病毒肺炎对机械行业的影响', '涉及', '基和通威外'),
#  ('能源汽车', '发布', '乘用车企业平均燃料消耗量与新能源汽车积分并行管理办法'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '松下'),
#  ('轻资产', '涉及', '老年'),
#  ('2019年业绩前瞻：稳健增长的一年', '涉及', 'WMF'),
#  ('行业观点', '涉及', 'SaaS'),
#  ('优异的辅助驾驶能力', '涉及', '中兴'),
#  ('深度产业运营+投资，健康、快乐、富足生态步入收获期', '涉及', '微医'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '科达利'),
#  ('惠州亿纬锂能股份有限公司', '发布', '关于'),
#  ('疫情凸显供应链地位', '涉及', '日本'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '中国科学院'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '武汉理工大学'),
#  ('投资建议', '涉及', '锦鸿'),
#  ('京运通', '发布', '资产收购协议'),
#  ('从两化协同看我国农业', '采用', '复合增速'),
#  ('华兰生物', '发布', '建议'),
#  ('安洁科技', '客户', '北京中石伟业科技股份有限公司'),
#  ('新的起点，从5G看云', '涉及', '2019Q2'),
#  ('华大', '发布', '建议'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '威马汽车'),
#  ('从SARS疫情复盘看新型冠状病毒肺炎对机械行业的影响', '涉及', '河北省住建厅'),
#  ('证券研究报告/行业动态报告', '涉及', '商城'),
#  ('从两化协同看我国农业自主', '涉及', '种业公司'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '武汉理工新能源公司'),
#  ('中央', '发布', '通知'),
#  ('2颗鸡蛋煎饼', '拥有', '家九毛九'),
#  ('2019年业绩前瞻：稳健增长的一年', '涉及', '双喜贴'),
#  ('投资建议', '涉及', 'ics'),
#  ('一城一策持续放松，货币财政双双发力', '涉及', '中华网'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '丰田'),
#  ('物业管理', '开展', '科技'),
#  ('远程办公产品之多媒体融合全面体验', '涉及', '北信源'),
#  ('凯发电气', '发布', '通知'),
#  ('国产化', '涉及', '国家工信部'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', 'ics'),
#  ('鉴彼时以观今日，化工行业疫情影响解析', '涉及', '武汉宏芯'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '中国物业服务百强企业研究报告'),
#  ('国产化', '涉及', '光伏行业协会'),
#  ('特斯拉专题系列报告（一）：', '涉及', '能源汽车'),
#  ('证券研究报告|行业投资策略', '涉及', '中央政治局会议'),
#  ('国产化', '涉及', '张家港'),
#  ('101教育PPT', '开展', '教育'),
#  ('深度跟踪报告', '涉及', 'Euromontior'),
#  ('Wi-Fi6：拐点已至', '涉及', 'WiFi6'),
#  ('百年疫情史：病毒改变了啥', '涉及', '亚洲流感'),
#  ('年金险', '发布', '筹划'),
#  ('行业评级', '涉及', '种业公司'),
#  ('鉴彼时以观今日，化工行业疫情影响解析', '涉及', '交通'),
#  ('证券研究报告/行业动态报告', '涉及', '沪深'),
#  ('宏基站', '发布', '规划'),
#  ('新能源汽车有限公司', '发布', '关于'),
#  ('技术支持', '客户', '物业'),
#  ('卓越的能耗', '涉及', '2018'),
#  ('雄韬股份子公司', '发布', '计划'),
#  ('行业评级', '涉及', '国家'),
#  ('半导体行情的风险是什么', '涉及', 'Atmel'),
#  ('投资建议', '涉及', '国产化'),
#  ('投资建议', '涉及', '融创中国'),
#  ('复星', '发布', '计划'),
#  ('轻资产', '涉及', '服务平台'),
#  ('药明', '发布', '意向'),
#  ('生态环境', '发布', '年报'),
#  ('轻资产', '涉及', '人寿保险'),
#  ('证券研究报告|电气设备', '涉及', '——'),
#  ('大消费联合系列报告：不可忽视的刚需消费', '涉及', 'Sullivan'),
#  ('游戏强劲，在线教育迎风起航', '涉及', '发达国家'),
#  ('继续深挖低线城市业务发展机会', '涉及', '季慧行'),
#  ('内外两维度看美股风险收益比', '涉及', '共和党'),
#  ('MARBL', '发布', '计划'),
#  ('大消费联合系列报告：不可忽视的刚需消费', '涉及', '日本'),
#  ('双寡头格局初现，高镍三元方向不可撼动', '涉及', '特斯拉秘密宏图'),
#  ('国家', '属于', '起化企'),
#  ('行业评级强于大市(维持评级)上次评级强于大市', '涉及', '万能'),
#  ('受益于微信商业生态提速', '涉及', '联想'),
#  ('保监会', '发布', '关于推动银行业'),
#  ('增速，是最大风险点', '涉及', '思佳讯'),
#  ('远程办公产品之多媒体融合全面体验', '涉及', '集团'),
#  ('证券研究报告|行业投资策略', '涉及', '招商蛇口'),
#  ('上海华熵', '发布', '战略合作协议书'),
#  ('迈过泥泞，方成涅槃——短期影响不改行业趋势，龙头公司韧性逐渐体现', '涉及', '首旅'),
#  ('看好/维持', '涉及', 'SARS'),
#  ('手机产业系列报告之二', '涉及', '仁宝'),
#  ('炬华科技', '发布', '关于'),
#  ('天源迪科”', '发布', '合作开发协议'),
#  ('会畅通讯', '发布', '建议'),
#  ('羊奶粉龙头，业绩增长', '涉及', '2011年'),
#  ('鉴彼时以观今日，化工行业疫情影响解析', '涉及', '电池'),
#  ('轻资产', '涉及', '基地'),
#  ('报告摘要：', '涉及', '华源01”'),
#  ('那未', '拥有', '九毛九以'),
#  ('特斯拉始入华，探析市场竞争力', '涉及', '中国电动'),
#  ('江苏', '发布', '规划'),
#  ('赛道优势显著，国际化辅助生殖新星崭露头角', '涉及', '精准'),
#  ('和硕', '客户', '台湾双鸿科技股份有限公司'),
#  ('各类传感器有望', '涉及', '中国'),
#  ('跟随大市(维持', '涉及', '柏林工厂'),
#  ('行业观点', '涉及', '通用'),
#  ('报告摘要：', '涉及', '华源'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '永升生活'),
#  ('新冠疫情医药行业专题报告', '涉及', '石药集团'),
#  ('证券研究报告', '涉及', '金科股份'),
#  ('半导体业务孕育巨大机会，业务', '涉及', '国盛证券电新组'),
#  ('游戏强劲，在线教育', '涉及', '教育部学校规建中心'),
#  ('他山之石，从龟甲万、味好美看调味品公司发展路径', '涉及', 'CAGR'),
#  ('行业评级', '涉及', '先锋种业'),
#  ('历次疫情的启示', '涉及', '阿联酋'),
#  ('国改提速，预焕新生', '涉及', '移动'),
#  ('估值与投资建议', '涉及', '集团'),
#  ('深圳市兆新能源股份有限公司', '发布', '公告'),
#  ('各类传感器有望', '涉及', '国内'),
#  ('上海证券交易所', '发布', '关于'),
#  ('国产化进程加快，补贴有望向上游零部件靠拢', '涉及', '日本丰田'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '保利地产业'),
#  ('央企物管旗舰驶入非住宅物业蓝海', '涉及', '上海科技馆'),
#  ('特斯拉有望重塑中国车市格局，看好从零到一的机会', '涉及', '现代'),
#  ('工商', '发布', '计划生育'),
#  ('迈过泥泞，方成涅槃——短期影响不改行业', '涉及', '旅行社'),
#  ('东方', '发布', '计划'),
#  ('美股', '拥有', '中东地缘风险'),
#  ('新冠疫情医药行业专题报告', '涉及', '国家卫生健康委'),
#  ('粮食会是明年通胀的风险因素吗', '涉及', '国外'),
#  ('国知发保', '发布', '关于'),
#  ('国家', '发布', '“十三五”国家科技创新规划'),
#  ('国产化', '涉及', '奥迪'),
#  ('深度跟踪报告', '涉及', '购物中心'),
#  ('软磁：无线充电开启黄金时代', '涉及', 'TodaKogyoCorporation'),
#  ('电池', '发布', '道路机动车辆生产企业及产品公告》新产品目录'),
#  ('基地', '发布', '关于对欧洲生产研发基地项目增加投资的议案'),
#  ('凯发电气股份有限公司', '发布', '国家企业技术中心认定管理办法'),
#  ('证券研究报告/行业深度报告', '涉及', '正极'),
#  ...]

# %% [markdown]
# ## 生成提交文件
#
# 根据biendata的要求生成提交文件
#
# 参考：https://www.biendata.com/competition/ccks_2020_5/make-submission/

# %%
final_answer = {'attrs': submit_attrs,
                'entities': submit_entities,
                'relationships': submit_relations,
                }


with open('output/answers.json', mode='w') as fw:
        json.dump(final_answer, fw, ensure_ascii=False, indent=4)
